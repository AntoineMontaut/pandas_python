# %% [markdown]
# ## Data Scientist Challenge

# %% [markdown]
# In this challenge you are assuming the position of a data scientist for a large corporation with offices in many states. The company you work for is looking to gain insights from its data from accross the many states that it does business over the course of the year 2014. The company runs many 'sales' over the course of the year in its states. The data you have is of the 10,000 different sales run in different states. Each sale lasts for a particular amount of time denotd by 'sale_start' and 'sale_end' columns. Along with each sale is the revenue for that particular sale.
#
# The company is primarily interested in determining what is happening to revenue over time and what strategy should be undertaken to maximize revenue.
#
# You don't need any advanced statistics for this assignment. Good exploration and visualizations will reveal everything you need to know about what is happening. Check out pandas time-series module documentation here - http://pandas.pydata.org/pandas-docs/stable/timeseries.html

# %% [markdown]
# Please fork the repository into your github profile, clone it and then start working on it locally.

# %%
# starter code
import pandas as pd
import numpy as np
import calendar

# %%
from bokeh.io import output_notebook, show, vplot
import bokeh.plotting as bk_plotting
import bokeh.layouts as bk_layouts
from bokeh.models import Legend
from bokeh.models.ranges import FactorRange
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="06df641a-f695-4ec0-80b9-5fbc9c35ef85">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.charts import Bar
from bokeh.charts import BoxPlot
from bokeh.charts import Histogram
from bokeh.models.ranges import Range1d

# %%
sales = pd.read_csv('data/sales.csv', parse_dates=['sale_start', 'sale_end'])

# %%
sales.head()
# Out:
#       state sale_start   sale_end  sale_key  revenue
# 0  Arkansas 2014-12-24 2014-12-24         0   1311.0
# 1   Florida 2014-10-15 2014-10-17         1    698.0
# 2      Iowa 2014-09-07 2014-09-07         2   1193.0
# 3   Indiana 2014-05-19 2014-05-22         3    469.0
# 4     Maine 2014-04-19 2014-04-19         4    334.0

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
# state         10000 non-null object
# sale_start    10000 non-null datetime64[ns]
# sale_end      10000 non-null datetime64[ns]
# sale_key      10000 non-null int64
# revenue       10000 non-null float64
# dtypes: datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 390.7+ KB

# %%
sales['sale_duration_int'] = (sales.sale_end - sales.sale_start).dt.days
sales['sale_duration'] = sales['sale_duration_int'].map(lambda t: '{} days'.format(t))
sales['sale_month'] = sales.sale_start.dt.month.map(lambda x: calendar.month_abbr[x])
sales['sale_month_int'] = sales.sale_start.dt.month
sales = sales[['state', 'sale_month_int', 'sale_month', 'sale_start', 'sale_end', 'sale_duration', 
               'sale_duration_int', 'sale_key', 'revenue']]
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

sales.head(3)
# Out:
#       state  sale_month_int sale_month sale_start   sale_end sale_duration  \
# 0  Arkansas              12        Dec 2014-12-24 2014-12-24        0 days
# 1   Florida              10        Oct 2014-10-15 2014-10-17        2 days
# 2      Iowa               9        Sep 2014-09-07 2014-09-07        0 days
#
#    sale_duration_int  sale_key  revenue
# 0                  0         0   1311.0
# 1                  2         1    698.0
# 2                  0         2   1193.0

# %%
g = sales.groupby(['state', 'sale_duration'])

# %%
sales_states_duration = g['revenue'].mean().unstack('sale_duration')

# %%
h = sales_states_duration.mean(axis=1)

# %%
sales = sales.sort_values('sale_duration')
sales.head()
# Out:
#            state  sale_month_int sale_month sale_start   sale_end  \
# 0       Arkansas              12        Dec 2014-12-24 2014-12-24
# 356        Texas              11        Nov 2014-11-08 2014-11-08
# 9438  California               7        Jul 2014-07-14 2014-07-14
# 9439     Indiana               2        Feb 2014-02-24 2014-02-24
# 8593  New Mexico              12        Dec 2014-12-18 2014-12-18
#
#      sale_duration  sale_duration_int  sale_key  revenue
# 0           0 days                  0         0   1311.0
# 356         0 days                  0       356   1206.0
# 9438        0 days                  0      9438    613.0
# 9439        0 days                  0      9439    464.0
# 8593        0 days                  0      8593   1157.0

# %%
width, height = 900, 600
p1 = Bar(sales.sort_values('sale_duration'), label='state', values='revenue', agg='mean', stack='sale_duration',
        title="Average revenue per state (per sale duration)", xlabel='', legend='top_right',
        plot_width=width, plot_height=height)

p2 = Bar(sales, label='state', values='revenue', agg='count', stack='sale_duration',
        title="Number of sales per state (per sale duration)", xlabel='', legend='top_right',
        plot_width=width, plot_height=height)

p3 = Bar(sales.sort_values('sale_month_int'), label='state', values='revenue', agg='count', stack='sale_month',
        title="Number of sales per state (per month)", xlabel='', legend='top_right',
        plot_width=width, plot_height=height)

p4 = BoxPlot(sales, label='state', values='revenue',
            xlabel='', ylabel='Revenue', title='Revenue per state', legend=None,
            plot_width=width, plot_height=height)

p5 = BoxPlot(sales, label='sale_month', values='revenue',
            xlabel='', ylabel='Revenue', title='Revenue per month', legend=None,
            plot_width=width, plot_height=height)
p5.x_range = FactorRange(factors=months)

gp = bk_layouts.column(p1, p2, p3, p4, p5)
show(gp)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="ff569b42-7fd3-4d82-bc38-870d0a04f057"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#ff569b42-7fd3-4d82-bc38-870d0a04f057").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ff569b42-7fd3-4d82-bc38-870d0a04f057");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ff569b42-7fd3-4d82-bc38-870d0a04f057' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6bda1d87-822d-4425-8dec-9d0f251ec2e9":{"roots":{"references":[{"attributes":{"data_source":{"id":"61e4cec7-e4ec-48bf-ac73-137c8ec7e400","type":"ColumnDataSource"},"glyph":{"id":"9d88d178-3e9e-4738-90ce-ac32bce632b9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"72c76c80-d0b7-45b2-b7d9-f4e524d09225","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"bdd93dfc-cfcb-4113-bdc8-471964b1cf67","type":"ColumnDataSource"},"glyph":{"id":"f69c945e-ebfa-41e9-8fe8-1a73e14ce69b","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"b93af4dd-56b3-4335-9b6b-1293562430cc","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1a874846-5fcf-4950-8659-ec2c48db5e7d","type":"ColumnDataSource"},"glyph":{"id":"b37067ef-e7d7-4115-a037-0cde29ed3423","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0002d2b5-0896-4d4f-b2e6-e0fe38eba785","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"ad8ea2a0-a7f8-43dd-9cb3-a4c4ba3e2407","type":"ColumnDataSource"},"glyph":{"id":"95d425e4-e860-4403-a830-90e180405da4","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"27e801c2-53be-4745-890f-00b59b0afc0b","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"f871ace8-22a9-404d-be0b-244e1cb628fa","type":"ColumnDataSource"},"glyph":{"id":"dd7eb4b1-6b34-4be5-8393-32b261c9a744","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"792fdb88-c63a-4f39-bb28-c63513c55225","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["width","line_color","line_alpha","fill_alpha","label","height","x","color","y"],"data":{"chart_index":[{"sale_month":"Aug","state":"Louisiana"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[48.0],"label":[{"sale_month":"Aug","state":"Louisiana"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["Aug"],"state":["Louisiana"],"width":[0.8],"x":["Louisiana"],"y":[137.0]}},"id":"1f1eefec-adc2-4153-95e9-4d302b0173b2","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bb37cc27-6f89-4785-98f0-73fd53006251","type":"Rect"},{"attributes":{"callback":null,"column_names":["width","line_color","line_alpha","fill_alpha","label","height","x","color","y"],"data":{"chart_index":[{"sale_month":"Jan","state":"Nevada"}],"color":["#00ad9c"],"fill_alpha":[0.8],"height":[53.0],"label":[{"sale_month":"Jan","state":"Nevada"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["Jan"],"state":["Nevada"],"width":[0.8],"x":["Nevada"],"y":[26.5]}},"id":"702c02dc-4378-464a-a149-9ee61ea312e6","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"66ca9015-2ee8-43b7-b4af-417c5ebda83e","type":"ColumnDataSource"},"glyph":{"id":"94afde70-0b31-4051-983b-e9e71dd363ab","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f36ca372-935e-496a-8919-adb15c2d5a34","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"632ca6bf-7da1-412f-86c1-110f42db776d","type":"ColumnDataSource"},"glyph":{"id":"4ebd2f56-920a-491a-b0ad-46c0ff260ee5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"62dc00ac-c3d7-4edf-9828-fa0419662ac8","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["width","line_color","line_alpha","fill_alpha","label","height","x","color","y"],"data":{"chart_index":[{"state":"Alaska"}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[60.0],"label":[{"state":"Alaska"}],"line_alpha":[1.0],"line_color":["black"],"state":["Alaska"],"width":[0.8],"x":["Alaska"],"y":[686.0]}},"id":"a7928d38-60e8-4774-832a-322ec6bb5d99","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["w ...

# %% [markdown]
# ### Split by semester

# %%
sales.head()
# Out:
#            state  sale_month_int sale_month sale_start   sale_end  \
# 0       Arkansas              12        Dec 2014-12-24 2014-12-24
# 356        Texas              11        Nov 2014-11-08 2014-11-08
# 9438  California               7        Jul 2014-07-14 2014-07-14
# 9439     Indiana               2        Feb 2014-02-24 2014-02-24
# 8593  New Mexico              12        Dec 2014-12-18 2014-12-18
#
#      sale_duration  sale_duration_int  sale_key  revenue
# 0           0 days                  0         0   1311.0
# 356         0 days                  0       356   1206.0
# 9438        0 days                  0      9438    613.0
# 9439        0 days                  0      9439    464.0
# 8593        0 days                  0      8593   1157.0

# %%
q1 = ['Jan', 'Feb', 'Mar']
q2 = ['Apr', 'May', 'Jun']
q3 = ['Jul', 'Aug', 'Sep']
q4 = ['Oct', 'Nov', 'Dec']

def to_quarter(month):
    global q1, q2, q3, q4
    if month in q1:
        return 'Q1'
    elif month in q2:
        return 'Q2'
    elif month in q3:
        return 'Q3'
    else:
        return 'Q4'
    
sales['quarter'] = sales.sale_month.map(to_quarter)
sales.head()
# Out:
#            state  sale_month_int sale_month sale_start   sale_end  \
# 0       Arkansas              12        Dec 2014-12-24 2014-12-24
# 356        Texas              11        Nov 2014-11-08 2014-11-08
# 9438  California               7        Jul 2014-07-14 2014-07-14
# 9439     Indiana               2        Feb 2014-02-24 2014-02-24
# 8593  New Mexico              12        Dec 2014-12-18 2014-12-18
#
#      sale_duration  sale_duration_int  sale_key  revenue quarter
# 0           0 days                  0         0   1311.0      Q4
# 356         0 days                  0       356   1206.0      Q4
# 9438        0 days                  0      9438    613.0      Q3
# 9439        0 days                  0      9439    464.0      Q1
# 8593        0 days                  0      8593   1157.0      Q4

# %%
width, height = 900, 600
p1 = Bar(sales.sort_values('quarter'), label='state', values='revenue', agg='count', stack='quarter',
        title="", xlabel='', ylabel='Number of sales', legend='top_right',
        plot_width=width, plot_height=height)

p2 = Bar(sales.sort_values('quarter'), label='state', values='revenue', agg='mean', stack='quarter',
        title="", xlabel='', ylabel='Average revenue', legend='top_right',
        plot_width=width, plot_height=height)

p3 = Bar(sales.sort_values('quarter'), label='state', values='revenue', agg='sum', stack='quarter',
        title="", xlabel='', ylabel='Total revenue', legend='top_right',
        plot_width=width, plot_height=height)

gp = bk_layouts.column(p1, p2, p3)
show(gp)

# %%
gr_month = sales.groupby('sale_month')['revenue']
sales_month = gr_month.agg(['sum', 'count', 'mean'])
sales_month.index = months
sales_month['month'] = months
sales_month.columns = ['Monthly_Revenue', 'Monthly_Sales', 'Average_Sale_Revenue', 'Month']
sales_month = sales_month[['Month', 'Monthly_Sales', 'Monthly_Revenue', 'Average_Sale_Revenue']]
sales_month
# Out:
#     Month  Monthly_Sales  Monthly_Revenue  Average_Sale_Revenue
# Jan   Jan            757         618229.0            816.682959
# Feb   Feb            892         846619.0            949.124439
# Mar   Mar            820         833648.0           1016.643902
# Apr   Apr            727         534894.0            735.755158
# May   May            791         537733.0            679.814159
# Jun   Jun            832         765917.0            920.573317
# Jul   Jul            806         707292.0            877.533499
# Aug   Aug            749         576577.0            769.795728
# Sep   Sep            895         770376.0            860.755307
# Oct   Oct            918         922144.0           1004.514161
# Nov   Nov            951         925434.0            973.116719
# Dec   Dec            862         838562.0            972.809745

# %%
np.arange(200,1800, 200)
sales['sale_type'] = pd.cut(sales.revenue.values, np.arange(200,1800, 200), 
                            labels=[' 200 < sale < 400', ' 400 < sale < 600',
                                    ' 600 < sale < 800', ' 800 < sale < 1000',
                                    '1000 < sale < 1200', '1200 < sale < 1400',
                                    '1400 < sale < 1600'])

# %%
width, height = 800, 300
p1 = Bar(sales, label='sale_duration', values='revenue', color='sale_duration', agg='mean', 
        title="Average revenue per sale duration", legend=None,
        plot_width=width, plot_height=height)

p2 = Bar(sales, label='sale_month', values='revenue', color='sale_month', agg='mean', 
        title="Average revenue per month", legend=None,
        plot_width=width, plot_height=height)
p2.x_range = FactorRange(factors=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                                  'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

p3 = Bar(sales, label='sale_month', values='revenue', color='sale_month', agg='sum', 
        title="Total revenue per month", legend=None,
        plot_width=width, plot_height=height)
p3.x_range = p2.x_range

p4 = Bar(sales, label='sale_month', values='revenue', agg='count', 
        title="Number of sales per month", legend=None,
        plot_width=width, plot_height=height)
p4.x_range = p2.x_range

show(bk_layouts.column(p1, p2, p3, p4))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="5b4e3b7a-19a9-48ca-8b35-190f16684370"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#5b4e3b7a-19a9-48ca-8b35-190f16684370").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5b4e3b7a-19a9-48ca-8b35-190f16684370");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5b4e3b7a-19a9-48ca-8b35-190f16684370' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c1313fb0-a11c-433d-a57a-78f90951eaab":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["label","y","line_color","line_alpha","color","height","width","fill_alpha","x"],"data":{"chart_index":[{"sale_duration":"2 days"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[894.4982050259274],"label":[{"sale_duration":"2 days"}],"line_alpha":[1.0],"line_color":["white"],"sale_duration":["2 days"],"width":[0.8],"x":["2 days"],"y":[447.2491025129637]}},"id":"0c627c19-0df8-4486-910d-0689bf7f0f30","type":"ColumnDataSource"},{"attributes":{},"id":"a3957076-be32-4f2c-a7e4-030bf5b0747c","type":"ToolEvents"},{"attributes":{},"id":"cc4c56bd-9c1f-41ba-8dd7-ffe10273ebce","type":"CategoricalTicker"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3aecba9b-ed2e-43f6-9a55-ff775902d95f","type":"Rect"},{"attributes":{"callback":null,"column_names":["label","y","line_color","line_alpha","color","height","width","fill_alpha","x"],"data":{"chart_index":[{"sale_month":"Apr"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[618229.0],"label":[{"sale_month":"Apr"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["Apr"],"width":[0.8],"x":["Apr"],"y":[309114.5]}},"id":"c2e3abfb-ac1a-4f57-b45d-644e1d24d74c","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"04840fe8-6388-43d4-a30c-9c22efc953c7","type":"Rect"},{"attributes":{"plot":{"id":"e54ed02a-6d91-473e-a7c1-affbecd3f0b3","subtype":"Chart","type":"Plot"}},"id":"5b4d01f1-9d83-44d9-b6c8-66e5ff95f97a","type":"SaveTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"93a08e41-b492-4076-bf6d-7241db2c2297","type":"Rect"},{"attributes":{"callback":null,"column_names":["label","y","line_color","line_alpha","color","height","width","fill_alpha","x"],"data":{"chart_index":[{"sale_month":"May"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[895.0],"label":[{"sale_month":"May"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["May"],"width":[0.8],"x":["May"],"y":[447.5]}},"id":"356ee556-8f25-445d-b0b3-5a7c24b6fe3f","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8e9f5e66-647c-4cfd-81c8-ea759b1d11b4","type":"Rect"},{"attributes":{"plot":{"id":"607fb541-284c-47b4-ba27-9d96b3243735","subtype":"Chart","type":"Plot"}},"id":"85b28831-48e3-414d-85d9-32093d49c5f7","type":"PanTool"},{"attributes":{"data_source":{"id":"aa23e864-4fb7-44d2-a842-aaf643ab4b42","type":"ColumnDataSource"},"glyph":{"id":"04840fe8-6388-43d4-a30c-9c22efc953c7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6b261864-fdbd-4263-8d07-3212d76e5642","type":"GlyphRenderer"},{"attributes":{},"id":"f656622b-c85c-452a-9381-90befbf4c2a8","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["label","y","line_color","line_alpha","color","height","width","fill_alpha","x"],"data":{"chart_index":[{"sale_month":"Aug"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[949.1244394618834],"label":[{"sale_month":"Aug"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["Aug"],"width":[0.8],"x":["Aug"],"y":[474.5622197309417]}},"id":"aa23e864-4fb7-44d2-a842-aaf643ab4b42","type":"ColumnDataSource"},{"attributes":{"plo ...

# %%
width, height = 400, 400
p0 = Bar(sales[sales.sale_duration_int==0], label='state', values='revenue', agg='mean', 
        title="Average revenue per state (same-day sale)", legend=None,
        plot_width=width, plot_height=height)
p1 = Bar(sales[sales.sale_duration_int==1], label='state', values='revenue', agg='mean', 
        title="Average revenue per state (1-day sale)", legend=None,
        plot_width=width, plot_height=height)
p2 = Bar(sales[sales.sale_duration_int==2], label='state', values='revenue', agg='mean', 
        title="Average revenue per state (2-day sale)", legend=None,
        plot_width=width, plot_height=height)
p3 = Bar(sales[sales.sale_duration_int==3], label='state', values='revenue', agg='mean', 
        title="Average revenue per state (3-day sale)", legend=None,
        plot_width=width, plot_height=height)

gp = bk_layouts.gridplot([[p0,p1], [p2,p3]])
show(gp)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1e3957a0-b9f4-47e5-8954-1b17eb5b5d4a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#
type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"5714c73c-80af-4578-b67f-262180ea4c82","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"5a7f87de-a384-45de-875e-8f66cd98c741","type":"Range1d"}},"id":"b058c96b-4951-4c5a-9d19-7a8020207f97","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"column_names":["line_color","label","color","width","y","line_alpha","height","fill_alpha","x"],"data":{"chart_index":["(812.4, 860.1]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[510.0],"label":["(812.4, 860.1]"],"line_alpha":[1.0],"line_color":["black"],"width":[47.62857142857138],"x":["836.25"],"y":[255.0]}},"id":"ff93dbb5-e7f4-47da-98d7-c62def98fea6","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fil ...

# %%
width, height = 440, 300
p1 = Histogram(sales[sales.revenue<=1000], 'revenue', title = 'Revenue <= 1000',
        plot_width=width, plot_height=height)
p2 = Histogram(sales[sales.revenue>1000], 'revenue', title = 'Revenue > 1000',
        plot_width=width, plot_height=height)

p1.y_range = Range1d(0,400)
p2.y_range = p1.y_range

gp = bk_layouts.row(p1,p2)
show(gp)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="84b1f740-91fa-4054-b749-2b062d2a5b8e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#84b1f740-91fa-4054-b749-2b062d2a5b8e").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("84b1f740-91fa-4054-b749-2b062d2a5b8e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '84b1f740-91fa-4054-b749-2b062d2a5b8e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e1985ec0-747d-477d-a5d1-e50c271edbfc":{"roots":{"references":[{"attributes":{"plot":{"id":"bbc3cc7e-9d01-4b62-a75d-2a562d8b1bcb","subtype":"Chart","type":"Plot"}},"id":"b0705ea0-c718-4100-8faa-97401500aa0f","type":"ResetTool"},{"attributes":{"data_source":{"id":"4cc5be87-c8b2-4e45-a38e-96d2f48e1846","type":"ColumnDataSource"},"glyph":{"id":"6172488c-3892-421d-a877-bd470a9eb432","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5e35469e-fa54-4a90-9e17-10d247ac4bb0","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","label","color","width","y","line_alpha","height","fill_alpha","x"],"data":{"chart_index":["(973.5, 1000.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[165.0],"label":["(973.5, 1000.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[26.529411764705856],"x":["986.75"],"y":[82.5]}},"id":"9be73479-7c50-4ce7-b3a9-3375def71e2a","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3dbb1606-0306-43af-a59b-4e7fbe92fe75","type":"ColumnDataSource"},"glyph":{"id":"f6b9425d-4192-4223-a5c5-f83a087124c4","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"439d9be2-7c68-4c60-afa5-4c8ed8ba6e47","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","label","color","width","y","line_alpha","height","fill_alpha","x"],"data":{"chart_index":["(681.6, 708.2]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[381.0],"label":["(681.6, 708.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[26.529411764705856],"x":["694.9000000000001"],"y":[190.5]}},"id":"e0734122-5f32-4dd5-b120-07c0b5a369ee","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0f8c9c3c-0b49-4405-8bfb-e5260d01d444","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","label","color","width","y","line_alpha","height","fill_alpha","x"],"data":{"chart_index":["(230.6, 257.2]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[21.0],"label":["(230.6, 257.2]"],"line_alpha":[1.0],"line_color":["black"],"width":[26.529411764705884],"x":["243.89999999999998"],"y":[10.5]}},"id":"ca369d3b-a073-48a6-acc2-83fa5d70995b","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"63314c30-72a0-47a0-86cd-74e8316272f1","type":"Rect"},{"attributes":{},"id":"d4d9bae1-9412-472c-a843-81c6a199be70","type":"ToolEvents"},{"attributes":{"callback":null,"column_names":["line_color","label","color","width","y","line_alpha","height","fill_alpha","x"],"data":{"chart_index":["(442.9, 469.4]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[184.0],"label":["(442.9, 469.4]"],"line_alpha":[1.0],"line_color":["black"],"width":[26.529411764705912],"x":["456.15"],"y":[92.0]}},"id":"be80aff3-e396-46e8-816d-4b74744ffe14","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a1de1335-64e2-4463-81b8-c5f2d8cd8aaa","type":"Rect"},{"attributes":{"data_source":{"id":"d5ee4c70-01f3-4c12-9304-eb75e9a2f956","type":"ColumnDataSource"},"glyph":{"id":"097776c3-9a21-4660-b907-aa043fe3b74d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"87da9a4e-27e9-4933-86a4-a030028af16e","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color ...

# %%
width, height = 900, 600
p1 = Bar(sales.sort_values(['sale_type']), label='sale_month', values='revenue', stack='sale_type', agg='count', 
        title="Number of sales per type of sale (per month)", legend='top_right',
        plot_width=width, plot_height=height)

p1.toolbar_location = 'above'
p1.y_range = Range1d(0, 1700)
p1.x_range = FactorRange(factors=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                                  'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

show(p1)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="366ff277-9542-4caf-83f0-4a9a6bfd7d05"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#366ff277-9542-4caf-83f0-4a9a6bfd7d05").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("366ff277-9542-4caf-83f0-4a9a6bfd7d05");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '366ff277-9542-4caf-83f0-4a9a6bfd7d05' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9e80e3f5-72ed-4e70-ab6e-09f3ce18f125":{"roots":{"references":[{"attributes":{"data_source":{"id":"7aae9b14-ed25-4f5b-bf49-27e8a80d0f97","type":"ColumnDataSource"},"glyph":{"id":"b7d161c2-347f-45c7-87b8-ec3e337052b9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3fe53b6a-2435-417e-92a1-c514ae09bed6","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","label","color","width","y","line_alpha","height","fill_alpha","x"],"data":{"chart_index":[{"sale_month":"Oct","sale_type":" 600 < sale < 800"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[161.0],"label":[{"sale_month":"Oct","sale_type":" 600 < sale < 800"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["Oct"],"sale_type":[" 600 < sale < 800"],"width":[0.8],"x":["Oct"],"y":[198.5]}},"id":"8d4b37fb-0777-4a67-9391-7569a3e038c0","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"eb843e3a-f2e8-48c3-8705-cf0d1177b895","type":"ColumnDataSource"},"glyph":{"id":"226ee01a-d4c7-45a2-b8f1-2cd4b104efb1","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"829ce3d8-16fb-4094-8a99-8297790f682e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","label","color","width","y","line_alpha","height","fill_alpha","x"],"data":{"chart_index":[{"sale_month":"Mar","sale_type":"1000 < sale < 1200"}],"color":["#00ad9c"],"fill_alpha":[0.8],"height":[29.0],"label":[{"sale_month":"Mar","sale_type":"1000 < sale < 1200"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["Mar"],"sale_type":["1000 < sale < 1200"],"width":[0.8],"x":["Mar"],"y":[633.5]}},"id":"b1ec9a07-2ba2-4eb5-9d43-d6ba918c2897","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"41e26775-6821-41cf-aaaf-ff43dac93010","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","label","color","width","y","line_alpha","height","fill_alpha","x"],"data":{"chart_index":[{"sale_month":"May","sale_type":"1200 < sale < 1400"}],"color":["#c33ff3"],"fill_alpha":[0.8],"height":[135.0],"label":[{"sale_month":"May","sale_type":"1200 < sale < 1400"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["May"],"sale_type":["1200 < sale < 1400"],"width":[0.8],"x":["May"],"y":[751.5]}},"id":"6da31347-a293-4a10-b5a6-0f6bdd281eb9","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d7248efd-a174-4772-9eca-a4740c4915c3","type":"ColumnDataSource"},"glyph":{"id":"5649af5e-160d-4dc4-b957-a7628a0bbc31","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"f94685c4-a794-4a98-8d88-f374e5539048","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"f0e7282e-5d4c-40fc-90ad-b88cf46f78fd","type":"ColumnDataSource"},"glyph":{"id":"d8797a22-adea-4c7f-9f30-743f8194b82f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5e5a6605-fede-4235-b013-798ba3656e6e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","label","color","width","y","line_alpha","height","fill_alpha","x"],"data":{"chart_index":[{"sale_month":"Jan","sale_type":"1000 < sale < 1200"}],"color":["#00ad9c"],"fill_alpha":[0.8],"height":[7.0],"label":[{"sale_month":"Jan","sale_type":"1000 < sale < 1200"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["Jan"],"sale_type":["1000 < sale < 1200"],"width":[0.8],"x":["Jan"],"y":[767.5]}},"id":"546b8ac5-e1e9-46e5-9f3f-aa146cd300ed","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f2426ef ...
