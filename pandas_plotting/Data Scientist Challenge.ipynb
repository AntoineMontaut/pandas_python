# %% [markdown]
# ## Data Scientist Challenge

# %% [markdown]
# In this challenge you are assuming the position of a data scientist for a large corporation with offices in many states. The company you work for is looking to gain insights from its data from accross the many states that it does business over the course of the year 2014. The company runs many 'sales' over the course of the year in its states. The data you have is of the 10,000 different sales run in different states. Each sale lasts for a particular amount of time denotd by 'sale_start' and 'sale_end' columns. Along with each sale is the revenue for that particular sale.
#
# The company is primarily interested in determining what is happening to revenue over time and what strategy should be undertaken to maximize revenue.
#
# You don't need any advanced statistics for this assignment. Good exploration and visualizations will reveal everything you need to know about what is happening. Check out pandas time-series module documentation here - http://pandas.pydata.org/pandas-docs/stable/timeseries.html

# %% [markdown]
# Please fork the repository into your github profile, clone it and then start working on it locally.

# %%
# starter code
import pandas as pd
import numpy as np
import calendar

# %%
from bokeh.io import output_notebook, show, vplot
import bokeh.plotting as bk_plotting
import bokeh.layouts as bk_layouts
from bokeh.models import Legend
from bokeh.models.ranges import FactorRange
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="737ff93c-c85a-4bb6-9864-7d9e6552a55a">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.charts import Bar
from bokeh.charts import BoxPlot
from bokeh.charts import Histogram
from bokeh.models.ranges import Range1d

# %%
sales = pd.read_csv('data/sales.csv', parse_dates=['sale_start', 'sale_end'])

# %%
sales.head()
# Out:
#       state sale_start   sale_end  sale_key  revenue
# 0  Arkansas 2014-12-24 2014-12-24         0   1311.0
# 1   Florida 2014-10-15 2014-10-17         1    698.0
# 2      Iowa 2014-09-07 2014-09-07         2   1193.0
# 3   Indiana 2014-05-19 2014-05-22         3    469.0
# 4     Maine 2014-04-19 2014-04-19         4    334.0

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
# state         10000 non-null object
# sale_start    10000 non-null datetime64[ns]
# sale_end      10000 non-null datetime64[ns]
# sale_key      10000 non-null int64
# revenue       10000 non-null float64
# dtypes: datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 390.7+ KB

# %%
sales['sale_duration_int'] = (sales.sale_end - sales.sale_start).dt.days
sales['sale_duration'] = sales['sale_duration_int'].map(lambda t: '{} days'.format(t))
sales['sale_month'] = sales.sale_start.dt.month.map(lambda x: calendar.month_abbr[x])
sales['sale_month_int'] = sales.sale_start.dt.month
sales = sales[['state', 'sale_month_int', 'sale_month', 'sale_start', 'sale_end', 'sale_duration', 
               'sale_duration_int', 'sale_key', 'revenue']]
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

sales.head(3)
# Out:
#       state  sale_month_int sale_month sale_start   sale_end sale_duration  \
# 0  Arkansas              12        Dec 2014-12-24 2014-12-24        0 days
# 1   Florida              10        Oct 2014-10-15 2014-10-17        2 days
# 2      Iowa               9        Sep 2014-09-07 2014-09-07        0 days
#
#    sale_duration_int  sale_key  revenue
# 0                  0         0   1311.0
# 1                  2         1    698.0
# 2                  0         2   1193.0

# %%
g = sales.groupby(['state', 'sale_duration'])

# %%
sales_states_duration = g['revenue'].mean().unstack('sale_duration')

# %%
h = sales_states_duration.mean(axis=1)

# %%
sales = sales.sort_values('sale_duration')
sales.head()
# Out:
#          state  sale_month_int sale_month sale_start   sale_end sale_duration  \
# 0     Arkansas              12        Dec 2014-12-24 2014-12-24        0 days
# 6459    Oregon               4        Apr 2014-04-06 2014-04-06        0 days
# 6458    Oregon               2        Feb 2014-02-28 2014-02-28        0 days
# 2294  Oklahoma              10        Oct 2014-10-07 2014-10-07        0 days
# 6454    Alaska               1        Jan 2014-01-31 2014-01-31        0 days
#
#       sale_duration_int  sale_key  revenue
# 0                     0         0   1311.0
# 6459                  0      6459    771.0
# 6458                  0      6458    856.0
# 2294                  0      2294    471.0
# 6454                  0      6454    647.0

# %%
width, height = 900, 600
p1 = Bar(sales.sort_values('sale_duration'), label='state', values='revenue', agg='mean', stack='sale_duration',
        title="Average revenue per state (per sale duration)", xlabel='', legend='top_right',
        plot_width=width, plot_height=height)

p2 = Bar(sales, label='state', values='revenue', agg='count', stack='sale_duration',
        title="Number of sales per state (per sale duration)", xlabel='', legend='top_right',
        plot_width=width, plot_height=height)

p3 = Bar(sales.sort_values('sale_month_int'), label='state', values='revenue', agg='count', stack='sale_month',
        title="Number of sales per state (per month)", xlabel='', legend='top_right',
        plot_width=width, plot_height=height)

p4 = BoxPlot(sales, label='state', values='revenue',
            xlabel='', ylabel='Revenue', title='Revenue per state', legend=None,
            plot_width=width, plot_height=height)

p5 = BoxPlot(sales, label='sale_month', values='revenue',
            xlabel='', ylabel='Revenue', title='Revenue per month', legend=None,
            plot_width=width, plot_height=height)
p5.x_range = FactorRange(factors=months)

gp = bk_layouts.column(p1, p2, p3, p4, p5)
show(gp)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="2fd5fe10-6aa8-413d-983f-1526d0f3eed4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#2fd5fe10-6aa8-413d-983f-1526d0f3eed4").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2fd5fe10-6aa8-413d-983f-1526d0f3eed4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2fd5fe10-6aa8-413d-983f-1526d0f3eed4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"dabdfed2-08cc-47da-a7f5-a456215ea2db":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":[{"sale_month":"Mar","state":"Idaho"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[11.0],"label":[{"sale_month":"Mar","state":"Idaho"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["Mar"],"state":["Idaho"],"width":[0.8],"x":["Idaho"],"y":[12.5]}},"id":"97013995-1497-46a9-8253-a91d476d93f3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"79168f59-bc5a-4136-a972-29133999713a","type":"ColumnDataSource"},"glyph":{"id":"0ae6b017-f8be-4dff-8f55-be90c9e31b94","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9d545462-e912-4854-987a-b0bf6487a34f","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"9ef4fa78-a574-4ee5-aaeb-e507f3242945","type":"Circle"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0fa84030-2245-47fb-9abf-0cf79c43eee3","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"805ba78e-b576-4ade-8645-a96b50fe85fc","type":"Rect"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":5},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"7f6cc1a3-a39e-45ac-916e-2a25ae4e895f","type":"Circle"},{"attributes":{"data_source":{"id":"b9d3ee2a-4b95-4104-bc22-1191d5d46c4f","type":"ColumnDataSource"},"glyph":{"id":"d454b5a7-a206-4683-a891-768e5fe22056","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6c1cd82e-7587-4de3-b430-e86b9f1dc344","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"de57235f-f342-455b-bdeb-9834b690eb57","type":"Rect"},{"attributes":{"data_source":{"id":"76ffcca9-1eb1-4f82-9b03-dbdcdb6fd30e","type":"ColumnDataSource"},"glyph":{"id":"43b9c917-a147-4ba7-ba8b-b52bf30d8f83","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cd23eeff-afe2-4cf9-b7bc-aff8b8589c83","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":[{"state":"Arkansas"}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[69.0],"label":[{"state":"Arkansas"}],"line_alpha":[1.0],"line_color":["black"],"state":["Arkansas"],"width":[0.8],"x":["Arkansas"],"y":[1193.5]}},"id":"387bb290-91cb-452f-988e-6d31bc6da41f","type":"ColumnDataSource"},{"attributes":{},"id":"c62304a6-1d2d-47c0-b753-530b7846e8c9","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":[{"sale_month":"Jul"}],"color":["DimGrey"],"fill_alpha":[0.8],"height":[259.25],"label":[{"sale_month":"Jul"}],"line_alpha":[1.0],"line_color":["black"],"sale_month":["Jul"],"width":[0.8],"x":["Jul"],"y":[769.375]}},"id":"9efa60e2-b8b5-4180-85d9-bf9fda5a53d3","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"l ...

# %% [markdown]
# ### Split by semester

# %%
sales.head()
# Out:
#          state  sale_month_int sale_month sale_start   sale_end sale_duration  \
# 0     Arkansas              12        Dec 2014-12-24 2014-12-24        0 days
# 6459    Oregon               4        Apr 2014-04-06 2014-04-06        0 days
# 6458    Oregon               2        Feb 2014-02-28 2014-02-28        0 days
# 2294  Oklahoma              10        Oct 2014-10-07 2014-10-07        0 days
# 6454    Alaska               1        Jan 2014-01-31 2014-01-31        0 days
#
#       sale_duration_int  sale_key  revenue
# 0                     0         0   1311.0
# 6459                  0      6459    771.0
# 6458                  0      6458    856.0
# 2294                  0      2294    471.0
# 6454                  0      6454    647.0

# %%
q1 = ['Jan', 'Feb', 'Mar']
q2 = ['Apr', 'May', 'Jun']
q3 = ['Jul', 'Aug', 'Sep']
q4 = ['Oct', 'Nov', 'Dec']

def to_quarter(month):
    global q1, q2, q3, q4
    if month in q1:
        return 'Q1'
    elif month in q2:
        return 'Q2'
    elif month in q3:
        return 'Q3'
    else:
        return 'Q4'
    
sales['quarter'] = sales.sale_month.map(to_quarter)
sales.head()
# Out:
#          state  sale_month_int sale_month sale_start   sale_end sale_duration  \
# 0     Arkansas              12        Dec 2014-12-24 2014-12-24        0 days
# 6459    Oregon               4        Apr 2014-04-06 2014-04-06        0 days
# 6458    Oregon               2        Feb 2014-02-28 2014-02-28        0 days
# 2294  Oklahoma              10        Oct 2014-10-07 2014-10-07        0 days
# 6454    Alaska               1        Jan 2014-01-31 2014-01-31        0 days
#
#       sale_duration_int  sale_key  revenue quarter
# 0                     0         0   1311.0      Q4
# 6459                  0      6459    771.0      Q2
# 6458                  0      6458    856.0      Q1
# 2294                  0      2294    471.0      Q4
# 6454                  0      6454    647.0      Q1

# %%
st = list(sales.state.unique())
for sales in st
sales.loc[(sales.quarter == 'Q1') & (sales.state == 'Arkansas'), 'revenue'].sum()
# Out:
# 21774.0

# %%
width, height = 900, 600
p1 = Bar(sales.sort_values('quarter'), label='state', values='revenue', agg='count', stack='quarter',
        title="", xlabel='', ylabel='Number of sales', legend='top_right',
        plot_width=width, plot_height=height)

p2 = Bar(sales.sort_values('quarter'), label='state', values='revenue', agg='mean', stack='quarter',
        title="", xlabel='', ylabel='Average revenue', legend='top_right',
        plot_width=width, plot_height=height)

p3 = Bar(sales.sort_values('quarter'), label='state', values='revenue', agg='sum', stack='quarter',
        title="", xlabel='', ylabel='Total revenue', legend='top_right',
        plot_width=width, plot_height=height)

gp = bk_layouts.column(p1, p2, p3)
show(gp)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="b4b9f948-677c-4345-83b0-9f7b57f1af35"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b4b9f948-677c-4345-83b0-9f7b57f1af35").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b4b9f948-677c-4345-83b0-9f7b57f1af35");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b4b9f948-677c-4345-83b0-9f7b57f1af35' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"738b6a91-986f-408b-ae4f-7dcf187c57b6":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a8c8e9ef-ea5b-4b15-83dc-12d96e6b84a6","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"30258cfb-d773-4d91-b56c-9d8f3a345eab","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"66853651-116e-473a-9bf4-7878978f117a","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5460230a-e5c6-4ef7-a9c2-a1ba8bb3caf8","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ebe0149a-c4d8-42f3-89d8-8f0a70a02dd6","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9bade680-7b3d-4710-a0d2-c4d8b098ec6c","type":"Rect"},{"attributes":{"data_source":{"id":"917f38e9-8074-4ead-8968-9ca60bcba547","type":"ColumnDataSource"},"glyph":{"id":"991be5ce-52df-4629-a0a1-cffc05aa5f20","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"66e35a50-5dc8-4cdc-bd3a-989675fca2fb","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4fb6ff7c-3e07-41d8-95ca-35ca3cf2cab5","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":[{"quarter":"Q3","state":"Maine"}],"color":["#407ee7"],"fill_alpha":[0.8],"height":[28165.0],"label":[{"quarter":"Q3","state":"Maine"}],"line_alpha":[1.0],"line_color":["white"],"quarter":["Q3"],"state":["Maine"],"width":[0.8],"x":["Maine"],"y":[147248.5]}},"id":"3e91e4d7-dc00-4f91-a1d9-0ff9c0cd5405","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d932695a-27a1-4bec-a7a8-e812d3bf6bfb","type":"ColumnDataSource"},"glyph":{"id":"f450c52d-d5d6-457a-b6bb-522e45fc8c21","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"90a2a768-c985-4dd3-825e-6ccfc014ac1c","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":[{"quarter":"Q2","state":"New Mexico"}],"color":["#5ab738"],"fill_alpha":[0.8],"height":[68.0],"label":[{"quarter":"Q2","state":"New Mexico"}],"line_alpha":[1.0],"line_color":["white"],"quarter":["Q2"],"state":["New Mexico"],"width":[0.8],"x":["New Mexico"],"y":[49.0]}},"id":"210c7867-7e3e-46ed-aeed-b58dfa2a71ae","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}}, ...

# %%
gr_month = sales.groupby('sale_month')['revenue']
sales_month = gr_month.agg(['sum', 'count', 'mean'])
sales_month.index = months
sales_month['month'] = months
sales_month.columns = ['Monthly_Revenue', 'Monthly_Sales', 'Average_Sale_Revenue', 'Month']
sales_month = sales_month[['Month', 'Monthly_Sales', 'Monthly_Revenue', 'Average_Sale_Revenue']]
sales_month
# Out:
#     Month  Monthly_Sales  Monthly_Revenue  Average_Sale_Revenue
# Jan   Jan            757         618229.0            816.682959
# Feb   Feb            892         846619.0            949.124439
# Mar   Mar            820         833648.0           1016.643902
# Apr   Apr            727         534894.0            735.755158
# May   May            791         537733.0            679.814159
# Jun   Jun            832         765917.0            920.573317
# Jul   Jul            806         707292.0            877.533499
# Aug   Aug            749         576577.0            769.795728
# Sep   Sep            895         770376.0            860.755307
# Oct   Oct            918         922144.0           1004.514161
# Nov   Nov            951         925434.0            973.116719
# Dec   Dec            862         838562.0            972.809745

# %%
np.arange(200,1800, 200)
sales['sale_type'] = pd.cut(sales.revenue.values, np.arange(200,1800, 200), 
                            labels=[' 200 < sale < 400', ' 400 < sale < 600',
                                    ' 600 < sale < 800', ' 800 < sale < 1000',
                                    '1000 < sale < 1200', '1200 < sale < 1400',
                                    '1400 < sale < 1600'])

# %%
width, height = 800, 300
p1 = Bar(sales, label='sale_duration', values='revenue', color='sale_duration', agg='mean', 
        title="Average revenue per sale duration", legend=None,
        plot_width=width, plot_height=height)

p2 = Bar(sales, label='sale_month', values='revenue', color='sale_month', agg='mean', 
        title="Average revenue per month", legend=None,
        plot_width=width, plot_height=height)
p2.x_range = FactorRange(factors=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                                  'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

p3 = Bar(sales, label='sale_month', values='revenue', color='sale_month', agg='sum', 
        title="Total revenue per month", legend=None,
        plot_width=width, plot_height=height)
p3.x_range = p2.x_range

p4 = Bar(sales, label='sale_month', values='revenue', agg='count', 
        title="Number of sales per month", legend=None,
        plot_width=width, plot_height=height)
p4.x_range = p2.x_range

show(bk_layouts.column(p1, p2, p3, p4))
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="e170ea49-8ac3-4364-9a74-f2246807cdb1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#e170ea49-8ac3-4364-9a74-f2246807cdb1").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e170ea49-8ac3-4364-9a74-f2246807cdb1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e170ea49-8ac3-4364-9a74-f2246807cdb1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a97ed3e3-2bac-4c1a-9590-8c9623069063":{"roots":{"references":[{"attributes":{"plot":{"id":"70893c90-dd55-4e36-98f4-662deb9bea69","subtype":"Chart","type":"Plot"}},"id":"19dc5740-0770-48fd-8354-bc6ff2e497eb","type":"ResetTool"},{"attributes":{"overlay":{"id":"ee334e20-1f22-41a8-96a6-43dd2680acf8","type":"BoxAnnotation"},"plot":{"id":"b94cd520-9960-4f45-b914-b4ec1d210582","subtype":"Chart","type":"Plot"}},"id":"79a277d6-1dbd-44f5-8a23-4fc2efaa8f0f","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"55d7b43f-bdfc-413c-b7f3-8bb1682ca499","type":"ColumnDataSource"},"glyph":{"id":"90615d70-e463-47b5-b304-cd99c2bd8a16","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"afbfd26d-e3dc-439e-afba-c6897a10b0a8","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":[{"sale_month":"Jun"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[877.5334987593052],"label":[{"sale_month":"Jun"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["Jun"],"width":[0.8],"x":["Jun"],"y":[438.7667493796526]}},"id":"c6a84fda-8f56-46bc-8a4a-c8972f4c3300","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":[{"sale_month":"Nov"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[918.0],"label":[{"sale_month":"Nov"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["Nov"],"width":[0.8],"x":["Nov"],"y":[459.0]}},"id":"6294617d-1b35-4a9c-a7ac-4be9a7f2d630","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5079d912-170c-4123-b03b-278439ccee0f","type":"Rect"},{"attributes":{"plot":{"id":"70893c90-dd55-4e36-98f4-662deb9bea69","subtype":"Chart","type":"Plot"}},"id":"46c22253-7f54-4f33-af64-2c3bc8f3f670","type":"HelpTool"},{"attributes":{"overlay":{"id":"c7359e25-ff47-4b94-b2cb-ed842347da01","type":"BoxAnnotation"},"plot":{"id":"95b8e589-de43-4d8d-8a1e-84b3c93358f1","subtype":"Chart","type":"Plot"}},"id":"86aedee1-a6ee-45be-a0eb-2c6e7c4c4893","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ba985d8a-4c75-4979-9a0d-5e253904a69f","type":"Rect"},{"attributes":{"axis_label":"Sale_Month","formatter":{"id":"9bb20125-3adf-48b2-b275-4be75807cf9b","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"b94cd520-9960-4f45-b914-b4ec1d210582","subtype":"Chart","type":"Plot"},"ticker":{"id":"2ee22a37-12db-4259-9b21-f0f30ae7d72d","type":"CategoricalTicker"}},"id":"5ce4b31b-b5be-4a24-aa6e-7429e8116118","type":"CategoricalAxis"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":[{"sale_duration":"3 days"}],"color":["#df5320"],"fill_alpha":[0.8],"height":[891.5507246376811],"label":[{"sale_duration":"3 days"}],"line_alpha":[1.0],"line_color":["white"],"sale_duration":["3 days"],"width":[0.8],"x":["3 days"],"y":[445.77536231884056]}},"id":"b36b7a76-76db-4572-9361-eebfc082a3c0","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":[{"sale_month":"Jun"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[707292.0],"label":[{"sale_month":"Jun"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["Jun"],"width":[0.8],"x":["Jun"],"y":[353646.0]}},"id":"eaa9d999-487e-49cf-81d ...

# %%
width, height = 400, 400
p0 = Bar(sales[sales.sale_duration_int==0], label='state', values='revenue', agg='mean', 
        title="Average revenue per state (same-day sale)", legend=None,
        plot_width=width, plot_height=height)
p1 = Bar(sales[sales.sale_duration_int==1], label='state', values='revenue', agg='mean', 
        title="Average revenue per state (1-day sale)", legend=None,
        plot_width=width, plot_height=height)
p2 = Bar(sales[sales.sale_duration_int==2], label='state', values='revenue', agg='mean', 
        title="Average revenue per state (2-day sale)", legend=None,
        plot_width=width, plot_height=height)
p3 = Bar(sales[sales.sale_duration_int==3], label='state', values='revenue', agg='mean', 
        title="Average revenue per state (3-day sale)", legend=None,
        plot_width=width, plot_height=height)

gp = bk_layouts.gridplot([[p0,p1], [p2,p3]])
show(gp)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="472343c1-5832-4f68-a565-504f5f5eb668"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#472343c1-5832-4f68-a565-504f5f5eb668").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("472343c1-5832-4f68-a565-504f5f5eb668");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '472343c1-5832-4f68-a565-504f5f5eb668' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8579b420-4fa6-4285-951b-8dc6fcf7d7e8":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8bf7b6c5-b94d-48c5-9712-c548f25d7bad","type":"Rect"},{"attributes":{"data_source":{"id":"acd91da0-6fa2-4290-b350-eba4eb3ccd52","type":"ColumnDataSource"},"glyph":{"id":"6216c157-5afe-4d29-874b-731574dc73a7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9c646f24-de0a-4909-aa3f-eb2d68911d98","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2f5507db-3f63-466e-8971-f5703eb8d1e0","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"aeaa5220-4398-491b-92fe-efd9a53bb1f7","type":"ColumnDataSource"},"glyph":{"id":"ec77f80e-1820-4220-8886-3d2f17a267c5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"87ecda59-7e75-4bef-85b6-f674eb957ba5","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b0542247-3e98-40e8-9c20-ed76ce5dcfb5","type":"Rect"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c55bdd52-ff4d-4987-9298-d9b3533b92e1","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":[{"state":"Georgia"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1227.0853658536585],"label":[{"state":"Georgia"}],"line_alpha":[1.0],"line_color":["white"],"state":["Georgia"],"width":[0.8],"x":["Georgia"],"y":[613.5426829268292]}},"id":"4299ff8e-e065-4f8f-83f4-6f953e86aa5b","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bffcc953-c8cf-426e-9b27-62392ab84e23","type":"Rect"},{"attributes":{"data_source":{"id":"e3349b02-faa4-4c14-ac3c-59240f8c283e","type":"ColumnDataSource"},"glyph":{"id":"586d4bf8-43b1-4e45-bbd2-f6a743890b6e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3f14f05e-d86f-4957-99fd-60de9ef27551","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5c647c38-626c-466c-b8ea-dda97e1c2160","type":"Rect"},{"attributes":{"data_source":{"id":"95d991eb-44b4-4956-8649-9bbb8c3419a9","type":"ColumnDataSource"},"glyph":{"id":"8c9cda1a-d2ea-4831-be0c-bd71517f6447","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e57c4333-6242-43dc-8a6a-759f13bea6b0","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"8f63d218-c93b-47dd-9743-c59ecd848128","type":"ColumnDataSource"},"glyph":{"id":"f112a895-f78e-47fc-bbb0-17bc42f27fb2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d9a1e636-e0f5- ...

# %%
width, height = 900, 300
p1 = Histogram(sales, 'revenue',
        plot_width=width, plot_height=height)
show(p1)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="6cf8aaeb-5ac3-4917-8b34-c57880a4c1a1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#6cf8aaeb-5ac3-4917-8b34-c57880a4c1a1").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6cf8aaeb-5ac3-4917-8b34-c57880a4c1a1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6cf8aaeb-5ac3-4917-8b34-c57880a4c1a1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7e31c78f-5fbc-4c85-9f7a-2574b6e96d63":{"roots":{"references":[{"attributes":{"axis_label":"revenue","formatter":{"id":"0b10b109-6eb5-45b5-b2ea-611bedfb757e","type":"BasicTickFormatter"},"plot":{"id":"d9ee1f83-23a0-4e71-9b69-773c121d14eb","subtype":"Chart","type":"Plot"},"ticker":{"id":"f762d533-cd6a-44ec-810b-2cd0d186a9b9","type":"BasicTicker"}},"id":"a976ae05-24a9-4483-bf32-85999c60aa45","type":"LinearAxis"},{"attributes":{"data_source":{"id":"e7c1e5bc-338e-4b9a-a80c-7afa06072af9","type":"ColumnDataSource"},"glyph":{"id":"ba1a15a8-245c-4515-b4c7-d09244e9ae63","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"852b21c5-e4f5-454c-b1f1-f73b40098014","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"87ee1192-5b93-4f94-bef7-fd8807eaae8f","type":"ColumnDataSource"},"glyph":{"id":"921d9a16-a05b-4f3a-864e-394acb83d126","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ac06c845-9898-4492-8076-67e60767e951","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":["(860.1, 907.7]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[379.0],"label":["(860.1, 907.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[47.62857142857138],"x":["883.9000000000001"],"y":[189.5]}},"id":"a05d8a4c-6ac1-4070-954e-1d23d349752e","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ed3695c8-e10b-4b5d-9cfb-70723a96d4f8","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":["(193.3, 240.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[37.0],"label":["(193.3, 240.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[47.628571428571405],"x":["217.10000000000002"],"y":[18.5]}},"id":"ff7e9a06-bbd6-4c36-8b80-e076e07627ed","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"44b9f3c1-900c-42e0-82aa-1a96d6052d3d","type":"Rect"},{"attributes":{"dimension":1,"plot":{"id":"d9ee1f83-23a0-4e71-9b69-773c121d14eb","subtype":"Chart","type":"Plot"},"ticker":{"id":"ff9a6ca7-0854-44cf-9a77-71b7c2a9cae5","type":"BasicTicker"}},"id":"b568744f-27dd-4bc5-92a4-960a1fb0a0d3","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":["(1336.3, 1384.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[276.0],"label":["(1336.3, 1384.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[47.62857142857138],"x":["1360.15"],"y":[138.0]}},"id":"17fa7610-5280-4bbf-a8f7-2ae75a1726ee","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"f664514b-8e48-4e0c-bb7e-aaefb645a2b4","type":"ColumnDataSource"},"glyph":{"id":"f13c4bc2-2895-4ffd-91a0-0c57d955add4","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"edd0473a-824b-46ed-9291-5a4f331986bf","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":["(479.0, 526.7]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[349.0],"label":["(479.0, 526.7]"],"line_alpha":[1.0],"line_color":["black"],"width":[47.62857142857143],"x":["502.85"],"y":[174.5]}},"id":"98a21575-a367-476d-b77a-2cd674615792","type":"ColumnDa ...

# %%
width, height = 440, 300
p1 = Histogram(sales[sales.revenue<=1000], 'revenue', title = 'Revenue <= 1000',
        plot_width=width, plot_height=height)
p2 = Histogram(sales[sales.revenue>1000], 'revenue', title = 'Revenue > 1000',
        plot_width=width, plot_height=height)

p1.y_range = Range1d(0,400)
p2.y_range = p1.y_range

gp = bk_layouts.row(p1,p2)
show(gp)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="bcf4394e-7ad6-47e6-8c06-5bd5fbdf5ed4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#bcf4394e-7ad6-47e6-8c06-5bd5fbdf5ed4").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bcf4394e-7ad6-47e6-8c06-5bd5fbdf5ed4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bcf4394e-7ad6-47e6-8c06-5bd5fbdf5ed4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"fd0d28e9-b2b4-4642-8033-d711abb00f70":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":["(1739.5, 1765.0]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":["(1739.5, 1765.0]"],"line_alpha":[1.0],"line_color":["black"],"width":[25.466666666666697],"x":["1752.25"],"y":[2.0]}},"id":"dd721a95-1fe8-4248-a1cf-0879a589eda8","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"7c8e97f0-1efc-4bda-bb58-5bfbf952aaa4","type":"ColumnDataSource"},"glyph":{"id":"4ecd9e85-dd81-4632-8479-6a75a5dc723e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"a5d7c728-f12f-4519-b5b9-9cc5187c1e0d","type":"GlyphRenderer"},{"attributes":{"axis_label":"Count( Revenue )","formatter":{"id":"16427f59-a8e1-41f7-9e61-5d4872a13be0","type":"BasicTickFormatter"},"plot":{"id":"df60fd71-2eda-4b5a-8d13-c665b898201d","subtype":"Chart","type":"Plot"},"ticker":{"id":"8f4f861c-b8ae-4aa5-8664-73724777d222","type":"BasicTicker"}},"id":"3787fce2-0074-4c94-a7d7-9dc661f0d433","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"df60fd71-2eda-4b5a-8d13-c665b898201d","subtype":"Chart","type":"Plot"},"ticker":{"id":"8f4f861c-b8ae-4aa5-8664-73724777d222","type":"BasicTicker"}},"id":"27008a4e-4d9d-4b6b-8c7e-02fda4d029ee","type":"Grid"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3f6f35e1-631c-458a-9bb1-62a22758eabc","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":["(761.2, 787.8]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[322.0],"label":["(761.2, 787.8]"],"line_alpha":[1.0],"line_color":["black"],"width":[26.529411764705856],"x":["774.5"],"y":[161.0]}},"id":"0c1bacf1-060f-4064-a0b6-3ccd435d8db3","type":"ColumnDataSource"},{"attributes":{"axis_label":"Count( Revenue )","formatter":{"id":"202c3032-60fc-4f99-8479-e234a8b0f9ef","type":"BasicTickFormatter"},"plot":{"id":"b33b9d56-396c-41eb-9f51-4a8e1ed1c3bf","subtype":"Chart","type":"Plot"},"ticker":{"id":"14da4645-d3ae-44a9-91f5-f7c25b5fa975","type":"BasicTicker"}},"id":"f86f29df-561f-4038-a771-f1c31921e9eb","type":"LinearAxis"},{"attributes":{"data_source":{"id":"77a38a28-a5cb-4ff6-bf35-9fdb20ff19a6","type":"ColumnDataSource"},"glyph":{"id":"e10cbd10-a7d9-4efc-80d7-f09aa7e3466d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"bdc57601-0a7c-41f3-b5aa-a409c8c18c2e","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fda61b02-60d1-497a-8a91-cc18a9c33f60","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":["(1408.5, 1433.9]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[101.0],"label":["(1408.5, 1433.9]"],"line_alpha":[1.0],"line_color":["black"],"width":[25.466666666666697],"x":["1421.2"],"y":[50.5]}},"id":"5a88c459-4d20-43dd-b17d-b61222a34ddd","type":"ColumnDataSource"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"27b1aa5f-1d98-435d-9388-9dbc2504b68c","type":"PanTool"},{"id":"10641fc0-04ed-4b94-9333-1e3556d97e7c","type":"WheelZoomTool"},{"id":"529ad9f7-b98b-4f5d-9c61-90fe670e8865","type":"BoxZoomTool"},{"id":"7a93b992-0b5f-4e35-a05f-e310b39dba36","type":"SaveTool"},{"id":"81b3ded4-fff1-4be8-8dc4-05633f25d589","type":"ResetTool"},{"id":"4ae1bafb-0c58-4e4d-91cb-e3257707afc ...

# %%
width, height = 900, 600
p1 = Bar(sales.sort_values(['sale_type']), label='sale_month', values='revenue', stack='sale_type', agg='count', 
        title="Number of sales per type of sale (per month)", legend='top_right',
        plot_width=width, plot_height=height)

p1.toolbar_location = 'above'
p1.y_range = Range1d(0, 1700)
p1.x_range = FactorRange(factors=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
                                  'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

show(p1)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="9c853ee4-0fb8-47d8-961d-70fb0df26115"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#9c853ee4-0fb8-47d8-961d-70fb0df26115").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9c853ee4-0fb8-47d8-961d-70fb0df26115");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9c853ee4-0fb8-47d8-961d-70fb0df26115' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f8c87af7-8f4f-4059-b1c4-de77159f1ebc":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f55dcef4-b056-4b7c-bf21-180015da86fa","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":[{"sale_month":"Nov","sale_type":"1000 < sale < 1200"}],"color":["#00ad9c"],"fill_alpha":[0.8],"height":[284.0],"label":[{"sale_month":"Nov","sale_type":"1000 < sale < 1200"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["Nov"],"sale_type":["1000 < sale < 1200"],"width":[0.8],"x":["Nov"],"y":[540.0]}},"id":"7c00e10c-412d-4d1b-aeeb-96187a5c74da","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":[{"sale_month":"Mar","sale_type":"1200 < sale < 1400"}],"color":["#c33ff3"],"fill_alpha":[0.8],"height":[57.0],"label":[{"sale_month":"Mar","sale_type":"1200 < sale < 1400"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["Mar"],"sale_type":["1200 < sale < 1400"],"width":[0.8],"x":["Mar"],"y":[676.5]}},"id":"78e8bfd6-9f93-4c09-861f-4bd7dc3a8b28","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f71581c0-1f4d-4127-a09c-66d88899c94d","type":"Rect"},{"attributes":{"data_source":{"id":"283002df-af13-4823-8847-d2dc86faf33c","type":"ColumnDataSource"},"glyph":{"id":"f404e8a5-43d5-49b0-a968-4be62df30219","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"9042b845-c64d-41e0-8d93-091214a89f80","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","color","label","width","height","line_alpha","y","fill_alpha","line_color"],"data":{"chart_index":[{"sale_month":"Apr","sale_type":"1200 < sale < 1400"}],"color":["#c33ff3"],"fill_alpha":[0.8],"height":[82.0],"label":[{"sale_month":"Apr","sale_type":"1200 < sale < 1400"}],"line_alpha":[1.0],"line_color":["white"],"sale_month":["Apr"],"sale_type":["1200 < sale < 1400"],"width":[0.8],"x":["Apr"],"y":[655.0]}},"id":"56074299-b807-4e43-8fed-a2baba564235","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ff35573e-7d7f-4be1-b1f6-3cba36fe7776","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"53f8cad6-d61f-40e9-a8d4-d60f1a83817d","type":"Rect"},{"attributes":{"plot":{"id":"98a7f4f5-d4dd-477f-a3fa-5155a06baa8d","subtype":"Chart","type":"Plot"}},"id":"a2ad5280-2a0a-496a-b986-0112c51ae5c7","type":"ResetTool"},{"attributes":{"data_source":{"id":"b9bdec7a-16eb-4b9b-9474-d50bf85f8264","type":"ColumnDataSource"},"glyph":{"id":"46084618-a302-4ced-bc39-5dd31fda95cf","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"172ec7a4-354d-417b-82bd-340d7fdd09d3","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"188d8687-c5ed-4a22-9617-e3272631bb43","type":"Rect"},{"attributes":{"data_source":{"id":"11 ...
