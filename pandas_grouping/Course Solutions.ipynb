# %% [markdown]
# # Course Solutions
#
# 1. [Split Apply Combine Basics](#1.-Split-Apply-Combine-Basics)
# 1. [Split Apply Combine More](#2.-Split-Apply-Combine-More)
# 1. [Merging Data](#3.-Merging-Data)
# 1. [Relational Databases](#4.-Relational-Databases)
# 1. [Case Study - Counting Pandas](#Case-Study---Counting-Pandas-Solutions)

# %% [markdown]
# # 1. Split Apply Combine Basics

# %%
college = pd.read_csv('data/college.csv')

# %% [markdown]
# ### Problem 1
# <span  style="color:green; font-size:16px">In the **`college`** DataFrame without using a groupby, which city name appears the most frequently?</span>

# %%
# your code here
college['CITY'].value_counts().head()
# Out:
# New York       87
# Chicago        78
# Houston        72
# Los Angeles    56
# Miami          51
# Name: CITY, dtype: int64

# %% [markdown]
# ### Problem 2
# <span  style="color:green; font-size:16px">Does the city **`Houston`** only appear in the state of **`Texas`**?</span>

# %%
# NO! There is a Houston, Missouri

# This uses slightly different boolean selection to grab a single column at the same time
college.loc[college['CITY'] == 'Houston', 'STABBR'].value_counts()
# Out:
# TX    71
# MO     1
# Name: STABBR, dtype: int64

# %% [markdown]
# ### Problem 3
# <span  style="color:green; font-size:16px">Find the maximum undergraduate population for each state?</span>

# %%
# your code here
college.groupby('STABBR')['UGDS'].max().head()
# Out:
# STABBR
# AK     12865.0
# AL     29851.0
# AR     21405.0
# AS      1276.0
# AZ    151558.0
# Name: UGDS, dtype: float64

# %% [markdown]
# ### Problem 4
# <span  style="color:green; font-size:16px">Among colleges that have the largest undergrad population for each state, what is the difference between the most and least populous college?</span>

# %%
# your code here

# from problem 3
largest_per_state = college.groupby('STABBR')['UGDS'].max()

largest_per_state.max() - largest_per_state.min()
# Out:
# 150956.0

# %% [markdown]
# ### Problem 5: Advanced
# <span  style="color:green; font-size:16px">Find the name and population of the largest college per state.</span>

# %%
# couple ways to do this

#trim down the DataFrame and put the institution name in the index
college_instm = college.set_index('INSTNM')[['STABBR', 'UGDS']]
college_instm.head()
# Out:
#                                     STABBR     UGDS
# INSTNM
# Alabama A & M University                AL   4206.0
# University of Alabama at Birmingham     AL  11383.0
# Amridge University                      AL    291.0
# University of Alabama in Huntsville     AL   5451.0
# Alabama State University                AL   4811.0

# %%
# group by state and use idxmax
max_colleges = college_instm.groupby('STABBR')['UGDS'].idxmax()

# %%
college_instm.loc[max_colleges]
# Out:
#                                                    STABBR      UGDS
# INSTNM
# University of Alaska Anchorage                         AK   12865.0
# The University of Alabama                              AL   29851.0
# University of Arkansas                                 AR   21405.0
# American Samoa Community College                       AS    1276.0
# University of Phoenix-Arizona                          AZ  151558.0
# Ashford University                                     CA   44744.0
# University of Colorado Boulder                         CO   25873.0
# University of Connecticut                              CT   18016.0
# George Washington University                           DC   10433.0
# University of Delaware                                 DE   18222.0
# Miami Dade College                                     FL   61470.0
# College of Micronesia-FSM                              FM    2344.0
# University of Georgia                                  GA   26738.0
# University of Guam                                     GU    3607.0
# University of Hawaii at Manoa                          HI   13667.0
# Kaplan University-Davenport Campus                     IA   40335.0
# Brigham Young University-Idaho                         ID   23865.0
# University of Illinois at Urbana-Champaign             IL   31875.0
# Ivy Tech Community College                             IN   77657.0
# Kansas State University                                KS   19727.0
# University of Kentucky                                 KY   21725.0
# Louisiana State University and Agricultural & M...     LA   24452.0
# University of Massachusetts-Amherst                    MA   21864.0
# University of Maryland-University College              MD   33892.0
# University of Maine                                    ME    8682.0
# College of the Marshall Islands                        MH    1078.0
# Michigan State University                              MI   38395.0
# University of Minnesota-Twin Cities                    MN   30135.0
# University of Missouri-Columbia                        MO   27276.0
# Northern Marianas College                              MP    1120.0
# University of Mississippi                              MS   17809.0
# Montana State University                               MT   13117.0
# North Carolina State University at Raleigh             NC   22925.0
# North Dakota State University-Main Campus              ND   11763.0
# University of Nebraska-Lincoln                         NE   19979.0
# Southern New Hampshire University                      NH   28035.0
# Rutgers University-New Brunswick                       NJ   34094.0
# Central New Mexico Community College                   NM   22767.0
# College of Southern Nevada                             NV   31149.0
# Excelsior College                                      NY   38426.0
# Ohio State University-Main Campus                      OH   43733.0
# Oklahoma State University-Main Campus                  OK   20636.0
# Portland Community College                             OR   28549.0
# Pennsylvania State University-Main Campus              PA   39958.0
# Instituto de Banca y Comercio Inc                      PR   19014.0
# Palau Community College                                PW     602.0
# Community College of Rhode Island                      RI   16644.0
# University of South Carolina-Columbia                  SC   24623.0
# South Dakota State University                          SD   10003.0
# The University of Tennessee-Knoxville                  TN   21396.0
# Lone Star College System                               TX   59920.0
# Western Governors University                           UT   44499.0
# Liberty University                                     VA   49340.0
# University of the Virgin Islands                       VI    1971.0
# University of Vermont                                  VT    9958.0
# University of Washington-Seattle Campus                WA   29468.0
# University of Wisconsin-Madison                        WI   29302.0
# American Public University System                      WV   44924.0
# University of Wyoming                                  WY    9910.0

# %%
# second way

# trim data
college_trim = college[['STABBR', 'UGDS', 'INSTNM']]

# sort by state then by population descending
college_trim = college_trim.sort_values(['STABBR', 'UGDS'], ascending=[True, False])


# group by state and take the first in the group
college_trim.groupby('STABBR').first()
# Out:
#             UGDS                                             INSTNM
# STABBR
# AK       12865.0                     University of Alaska Anchorage
# AL       29851.0                          The University of Alabama
# AR       21405.0                             University of Arkansas
# AS        1276.0                   American Samoa Community College
# AZ      151558.0                      University of Phoenix-Arizona
# CA       44744.0                                 Ashford University
# CO       25873.0                     University of Colorado Boulder
# CT       18016.0                          University of Connecticut
# DC       10433.0                       George Washington University
# DE       18222.0                             University of Delaware
# FL       61470.0                                 Miami Dade College
# FM        2344.0                          College of Micronesia-FSM
# GA       26738.0                              University of Georgia
# GU        3607.0                                 University of Guam
# HI       13667.0                      University of Hawaii at Manoa
# IA       40335.0                 Kaplan University-Davenport Campus
# ID       23865.0                     Brigham Young University-Idaho
# IL       31875.0         University of Illinois at Urbana-Champaign
# IN       77657.0                         Ivy Tech Community College
# KS       19727.0                            Kansas State University
# KY       21725.0                             University of Kentucky
# LA       24452.0  Louisiana State University and Agricultural & ...
# MA       21864.0                University of Massachusetts-Amherst
# MD       33892.0          University of Maryland-University College
# ME        8682.0                                University of Maine
# MH        1078.0                    College of the Marshall Islands
# MI       38395.0                          Michigan State University
# MN       30135.0                University of Minnesota-Twin Cities
# MO       27276.0                    University of Missouri-Columbia
# MP        1120.0                          Northern Marianas College
# MS       17809.0                          University of Mississippi
# MT       13117.0                           Montana State University
# NC       22925.0         North Carolina State University at Raleigh
# ND       11763.0          North Dakota State University-Main Campus
# NE       19979.0                     University of Nebraska-Lincoln
# NH       28035.0                  Southern New Hampshire University
# NJ       34094.0                   Rutgers University-New Brunswick
# NM       22767.0               Central New Mexico Community College
# NV       31149.0                         College of Southern Nevada
# NY       38426.0                                  Excelsior College
# OH       43733.0                  Ohio State University-Main Campus
# OK       20636.0              Oklahoma State University-Main Campus
# OR       28549.0                         Portland Community College
# PA       39958.0          Pennsylvania State University-Main Campus
# PR       19014.0                  Instituto de Banca y Comercio Inc
# PW         602.0                            Palau Community College
# RI       16644.0                  Community College of Rhode Island
# SC       24623.0              University of South Carolina-Columbia
# SD       10003.0                      South Dakota State University
# TN       21396.0              The University of Tennessee-Knoxville
# TX       59920.0                           Lone Star College System
# UT       44499.0                       Western Governors University
# VA       49340.0                                 Liberty University
# VI        1971.0                   University of the Virgin Islands
# VT        9958.0                              University of Vermont
# WA       29468.0            University of Washington-Seattle Campus
# WI       29302.0                    University of Wisconsin-Madison
# WV       44924.0                  American Public University System
# WY        9910.0                              University of Wyoming

# %% [markdown]
# ### Problem 6
# <span  style="color:green; font-size:16px">Do distance only schools tend to have more or less student population than non-distance-only schools?</span>

# %%
# They have more
college.groupby('DISTANCEONLY')['UGDS'].mean()
# Out:
# DISTANCEONLY
# 0.0    2334.648135
# 1.0    6245.743590
# Name: UGDS, dtype: float64

# %% [markdown]
# ### Problem 7
# <span  style="color:green; font-size:16px">Do distance only schools tend to be more or less religously affiliated than non-distance-only schools?</span>

# %%
# Less
college.groupby('DISTANCEONLY')['RELAFFIL'].mean()
# Out:
# DISTANCEONLY
# 0.0    0.149635
# 1.0    0.050000
# Name: RELAFFIL, dtype: float64

# %% [markdown]
# ### Problem 8
# <span  style="color:green; font-size:16px">What state has the lowest percentage of currently operating schools of those that have religious affiliation?</span>

# %%
# your code here
cr = college[college['RELAFFIL'] == 1]

# Utah. Answer makes sense.
cr.groupby(['STABBR'])['CURROPER'].mean().sort_values().head()
# Out:
# STABBR
# UT    0.400000
# AZ    0.444444
# NV    0.500000
# CA    0.585366
# CT    0.647059
# Name: CURROPER, dtype: float64

# %% [markdown]
# ### Problem 9
# <span  style="color:green; font-size:16px">Trim the **`college`** DataFrame to only the 'race' columns - those beginning with **`UGDS_`**. Create a new column called **`UGDS_OTHER`** that is the sum of any race column that averages under 4% for the entire dataset.</span>

# %%
# trim dataframe
df_race = college.filter(like='UGDS_')

race_average = df_race.mean()

race_average
# Out:
# UGDS_WHITE    0.510207
# UGDS_BLACK    0.189997
# UGDS_HISP     0.161635
# UGDS_ASIAN    0.033544
# UGDS_AIAN     0.013813
# UGDS_NHPI     0.004569
# UGDS_2MOR     0.023950
# UGDS_NRA      0.016086
# UGDS_UNKN     0.045181
# dtype: float64

# %%
# keep only those less than 4%
other_race = race_average[race_average < .04]

other_race
# Out:
# UGDS_ASIAN    0.033544
# UGDS_AIAN     0.013813
# UGDS_NHPI     0.004569
# UGDS_2MOR     0.023950
# UGDS_NRA      0.016086
# dtype: float64

# %%
# get the column names
race_columns = other_race.index

race_columns
# Out:
# Index(['UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI', 'UGDS_2MOR', 'UGDS_NRA'], dtype='object')

# %%
# grab the columns and sum accross the rows
df_race['UGDS_OTHER'] = df_race[race_columns].sum(axis=1)

# can drop the low percentage columns
df_race.drop(race_columns, axis=1).head(10)
# Out:
#    UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_UNKN  UGDS_OTHER
# 0      0.0333      0.9353     0.0055     0.0138      0.0121
# 1      0.5922      0.2600     0.0283     0.0100      0.1094
# 2      0.2990      0.4192     0.0069     0.2715      0.0034
# 3      0.6988      0.1255     0.0382     0.0350      0.1025
# 4      0.0158      0.9208     0.0121     0.0137      0.0376
# 5      0.7825      0.1119     0.0348     0.0026      0.0682
# 6      0.7255      0.2613     0.0044     0.0019      0.0069
# 7      0.7823      0.1200     0.0191     0.0334      0.0451
# 8      0.5328      0.3376     0.0074     0.0246      0.0975
# 9      0.8507      0.0704     0.0248     0.0140      0.0401

# %% [markdown]
# ### Problem 10
# <span  style="color:green; font-size:16px">Use the column **`UG25ABV`** and the **`quantile`** Series function to get 5 evenly spaced quantiles (use 6 numbers). Use this output to create a categorical variable using the **`cut`** function and label the bins Youngest, Young, Average, Old, Oldest and assign it to the **`AGEGROUP`** column.
#
# Then find the average SAT math scores by AGEGROUP. Any surprising result?</span>

# %%
# your code here
quants = college.UG25ABV.quantile([0, .2, .4, .6, .8, 1])
college['AGEGROUP'] = pd.cut(college.UG25ABV, quants, labels=['Youngest', 'Young', 'Average', 'Old', 'Oldest'])
college.groupby('AGEGROUP')['SATMTMID'].mean()
# Out:
# AGEGROUP
# Youngest    547.380645
# Young       502.910072
# Average     491.941176
# Old         481.230769
# Oldest      482.333333
# Name: SATMTMID, dtype: float64

# %% [markdown]
# ### Problem 11
# <span  style="color:green; font-size:16px">Which are top 5 historically black colleges that have the highest white percentage?</span>

# %%
# your code here
college.loc[college.HBCU == 1, ['INSTNM', 'UGDS_WHITE']].sort_values('UGDS_WHITE', ascending=False).head()
# Out:
#                                            INSTNM  UGDS_WHITE
# 4021                      Bluefield State College      0.8437
# 17                Gadsden State Community College      0.6921
# 4050               West Virginia State University      0.5816
# 48                Shelton State Community College      0.5613
# 55    H Councill Trenholm State Community College      0.3951

# %% [markdown]
# ### Problem 12: Advanced
# <span  style="color:green; font-size:16px">Again make a DataFrame of all the race percentage columns. Read the documentation on the **`mul`** DataFrame method and use it to multiply the race percentage DataFrame to get an actual population of each race.</span>

# %%
# your code here
df_race = college.filter(like='UGDS_')

# %%
df_race.mul(college['UGDS'], axis=0).round(0).head(15)
# Out:
#     UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# 0        140.0      3934.0       23.0         8.0       10.0        8.0
# 1       6741.0      2960.0      322.0       590.0       25.0        8.0
# 2         87.0       122.0        2.0         1.0        0.0        0.0
# 3       3809.0       684.0      208.0       205.0       78.0        1.0
# 4         76.0      4430.0       58.0         9.0        5.0        3.0
# 5      23358.0      3340.0     1039.0       316.0      113.0       27.0
# 6       1155.0       416.0        7.0         4.0        7.0        0.0
# 7       2340.0       359.0       57.0        16.0       47.0        3.0
# 8       2293.0      1453.0       32.0        95.0       19.0        7.0
# 9      17451.0      1444.0      509.0       466.0      152.0        0.0
# 10       942.0       130.0       23.0        61.0       12.0        0.0
# 11       805.0       755.0       85.0        22.0        4.0        6.0
# 12         9.0       282.0       12.0         3.0        0.0        0.0
# 13       159.0       316.0        8.0         8.0        8.0        5.0
# 14      1108.0       421.0       88.0        35.0       14.0        5.0
#
#     UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# 0         0.0      25.0       58.0
# 1       419.0     204.0      114.0
# 2         0.0       0.0       79.0
# 3        94.0     181.0      191.0
# 4        47.0     117.0       66.0
# 5       779.0     800.0       78.0
# 6         0.0       0.0        3.0
# 7        52.0      17.0      100.0
# 8       128.0     171.0      106.0
# 9         0.0     205.0      287.0
# 10        6.0       0.0        6.0
# 11       26.0       0.0       24.0
# 12        1.0      15.0        0.0
# 13        0.0       1.0       17.0
# 14       44.0       2.0       12.0

# %% [markdown]
# # 2. Split Apply Combine More

# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = 40
hou = pd.read_csv('data/coh_employee.csv')

# %% [markdown]
# ## Problem 1
# <span  style="color:green; font-size:16px">What are the 5 least common departments?</span>

# %%
hou.DEPARTMENT.value_counts().tail()
# Out:
# Houston Information Tech Svcs    9
# Planning & Development           7
# Mayor's Office                   5
# City Controller's Office         5
# Convention and Entertainment     1
# Name: DEPARTMENT, dtype: int64

# %% [markdown]
# ### Problem 2
# <span  style="color:green; font-size:16px">Filter out departments with less than 50 occurences and save it to **`hou_filter`**. Then test your code by outputing the frequencies of all the remaining departments. </span>

# %%
hou_filter = hou.groupby('DEPARTMENT').filter(lambda df: len(df) >= 50)

hou_filter.DEPARTMENT.value_counts()
# Out:
# Houston Police Department-HPD     638
# Houston Fire Department (HFD)     384
# Public Works & Engineering-PWE    343
# Health & Human Services           110
# Houston Airport System (HAS)      106
# Parks & Recreation                 74
# Name: DEPARTMENT, dtype: int64

# %% [markdown]
# ### Problem 3
# <span  style="color:green; font-size:16px">Filter out departments from the original **`hou`** DataFrame with average salaries less than $70,000 and save it to **`hou_filter_salary`**. Then test your code by outputing the average salaries for the remaining departments.</span>

# %%
hou_filter_salary = hou.groupby('DEPARTMENT').filter(lambda df: df['BASE_SALARY'].mean() >= 70000)

# %%
# added astype(int) to remove decimals
hou_filter_salary.groupby('DEPARTMENT')['BASE_SALARY'].mean().astype(int)
# Out:
# DEPARTMENT
# Finance                           79650
# Houston Information Tech Svcs     76112
# Legal Department                 104959
# Mayor's Office                    86489
# Name: BASE_SALARY, dtype: int64

# %% [markdown]
# ### Problem 4
# <span  style="color:green; font-size:16px">Filter *`for`* those departments from the original **`hou`** DataFrame with average salaries of at least 65,000 or having at least 25 unique position titles. Save result to **`hou_more`**</span>

# %%
def more(df):
    if (df['BASE_SALARY'].mean() > 65000) | (df['POSITION_TITLE'].nunique() >= 25):
        return True
    return False

hou_more = hou.groupby('DEPARTMENT').filter(more)

# %%
hou_more.shape
# Out:
# (1696, 31)

# %% [markdown]
# ### Problem 5: Advanced
# <span  style="color:green; font-size:16px">Find a way to do problem 4 without using the **`filter`** method. Make clever use of aggregate groupby and boolean logic</span>

# %%
# do aggregations for each boolean piece separately
salary_grp = hou.groupby('DEPARTMENT')['BASE_SALARY'].mean()
uniq_grp = hou.groupby('DEPARTMENT')['POSITION_TITLE'].nunique()

salary_grp.head()
# Out:
# DEPARTMENT
# Admn. & Regulatory Affairs      50890.551724
# City Controller's Office        55711.600000
# City Council                    59089.222222
# Convention and Entertainment    38397.000000
# Dept of Neighborhoods (DON)     47092.882353
# Name: BASE_SALARY, dtype: float64

# %%
uniq_grp.head()
# Out:
# DEPARTMENT
# Admn. & Regulatory Affairs      19
# City Controller's Office         3
# City Council                     7
# Convention and Entertainment     1
# Dept of Neighborhoods (DON)     14
# Name: POSITION_TITLE, dtype: int64

# %%
# create boolean criteria

deps = (salary_grp > 65000) | (uniq_grp >= 25)

deps
# Out:
# DEPARTMENT
# Admn. & Regulatory Affairs        False
# City Controller's Office          False
# City Council                      False
# Convention and Entertainment      False
# Dept of Neighborhoods (DON)       False
# Finance                            True
# Fleet Management Department       False
# General Services Department       False
# Health & Human Services            True
# Housing and Community Devp.       False
# Houston Airport System (HAS)       True
# Houston Emergency Center (HEC)    False
# Houston Fire Department (HFD)      True
# Houston Information Tech Svcs      True
# Houston Police Department-HPD      True
# Human Resources Dept.             False
# Legal Department                   True
# Library                           False
# Mayor's Office                     True
# Municipal Courts Department       False
# Parks & Recreation                 True
# Planning & Development            False
# Public Works & Engineering-PWE     True
# Solid Waste Management            False
# dtype: bool

# %%
# filter Series with itself and grab index values
deps_true = deps[deps].index.values

deps_true
# Out:
# array(['Finance', 'Health & Human Services',
#        'Houston Airport System (HAS)', 'Houston Fire Department (HFD)',
#        'Houston Information Tech Svcs', 'Houston Police Department-HPD',
#        'Legal Department', "Mayor's Office", 'Parks & Recreation',
#        'Public Works & Engineering-PWE'], dtype=object)

# %%
hou_more_check = hou[hou.DEPARTMENT.isin(deps_true)]

# %%
# can check equality of dataframes with equals method
hou_more.equals(hou_more_check)
# Out:
# True

# %% [markdown]
# ### Problem 6: Advanced
# <span  style="color:green; font-size:16px">Group by department, gender and race and get the mean, min and max base salary for each group. Also get the number of unique position titles and the most frequent position title for each group. Rename each aggregation to something that makes sense. Then remove the top level of the column index. Hint: This [stackoverflow answer](http://stackoverflow.com/questions/15222754/group-by-pandas-dataframe-and-select-most-common-string-factor) will be useful </span>

# %%
df = hou.groupby(['DEPARTMENT', 'GENDER','RACE']).agg({'BASE_SALARY':{'salary_mean':'mean',
                                                                'salary_min':'min',
                                                                'salary_max':'max'},
                                                 'POSITION_TITLE':{'unique_positions':'nunique',
                                                                  'most_frequent_position':lambda x: x.value_counts().index[0]}})

# %%
df.columns = df.columns.droplevel(0)

# %%
df.head(12)
# Out:
#                                                              salary_min  \
# DEPARTMENT                 GENDER RACE
# Admn. & Regulatory Affairs Female Asian/Pacific Islander        37710.0
#                                   Black or African American     33550.0
#                                   Hispanic/Latino               28205.0
#                                   White                         33280.0
#                            Male   Black or African American     29557.0
#                                   Hispanic/Latino               35318.0
#                                   White                        103776.0
# City Controller's Office   Female Asian/Pacific Islander        59077.0
#                                   Black or African American     55536.0
#                                   Hispanic/Latino               64251.0
#                            Male   Black or African American     42640.0
# City Council               Female Black or African American    100000.0
#
#                                                                salary_mean  \
# DEPARTMENT                 GENDER RACE
# Admn. & Regulatory Affairs Female Asian/Pacific Islander      72293.666667
#                                   Black or African American   49727.500000
#                                   Hispanic/Latino             36616.400000
#                                   White                       47664.666667
#                            Male   Black or African American   29827.500000
#                                   Hispanic/Latino             35318.000000
#                                   White                      122096.000000
# City Controller's Office   Female Asian/Pacific Islander      59077.000000
#                                   Black or African American   56295.000000
#                                   Hispanic/Latino             64251.000000
#                            Male   Black or African American   42640.000000
# City Council               Female Black or African American  100000.000000
#
#                                                              salary_max  \
# DEPARTMENT                 GENDER RACE
# Admn. & Regulatory Affairs Female Asian/Pacific Islander       130416.0
#                                   Black or African American     72741.0
#                                   Hispanic/Latino               47341.0
#                                   White                         62129.0
#                            Male   Black or African American     30098.0
#                                   Hispanic/Latino               35318.0
#                                   White                        140416.0
# City Controller's Office   Female Asian/Pacific Islander        59077.0
#                                   Black or African American     57054.0
#                                   Hispanic/Latino               64251.0
#                            Male   Black or African American     42640.0
# City Council               Female Black or African American    100000.0
#
#                                                              unique_positions  \
# DEPARTMENT                 GENDER RACE
# Admn. & Regulatory Affairs Female Asian/Pacific Islander                    3
#                                   Black or African American                 8
#                                   Hispanic/Latino                           4
#                                   White                                     3
#                            Male   Black or African American                 2
#                                   Hispanic/Latino                           1
#                                   White                                     2
# City Controller's Office   Female Asian/Pacific Islander                    1
#                                   Black or African American                 1
#                                   Hispanic/Latino                           1
#                            Male   Black or African American                 1
# City Council               Female Black or African American                 1
#
#                                                                                most_frequent_position
# DEPARTMENT                 GENDER RACE
# Admn. & Regulatory Affairs Female Asian/Pacific Islander            3-1-1 TELECOMMUNICATOR SUPERVISOR
#                                   Black or African American                             STAFF ANALYST
#                                   Hispanic/Latino                              ANIMAL CARE TECHNICIAN
#                                   White                            ANIMAL ENFORCEMENT OFFICER TRAINEE
#                            Male   Black or African American                    ANIMAL CARE TECHNICIAN
#                                   Hispanic/Latino                   CUSTOMER SERVICE REPRESENTATIVE I
#                                   White                      DEPUTY ASSISTANT DIRECTOR (EXECUTIVE LEV
# City Controller's Office   Female Asian/Pacific Islander                ASSISTANT CITY CONTROLLER III
#                                   Black or African American                  ADMINISTRATIVE ASSISTANT
#                                   Hispanic/Latino                            ADMINISTRATIVE ASSISTANT
#                            Male   Black or African American                       FINANCIAL ANALYST I
# City Council               Female Black or African American     SENIOR COUNCIL AIDE (EXECUTIVE LEVEL)

# %% [markdown]
# ### Problem 7
# <span  style="color:green; font-size:16px"> Create a column **`is_max`** that is equal to 1 if the base salary is currently the max base salary (out of all previous rows) for that department and 0 otherwise. See sample data below.</span>

# %%
hou_1 = hou[['DEPARTMENT', 'BASE_SALARY']].copy()
hou_1['is_max'] = hou_1.groupby('DEPARTMENT')['BASE_SALARY'].transform(lambda x: x == x.cummax())

# %%
hou_1.head(20)
# Out:
#                         DEPARTMENT  BASE_SALARY  is_max
# 0      Municipal Courts Department     121862.0     1.0
# 1                          Library      26125.0     1.0
# 2    Houston Police Department-HPD      45279.0     1.0
# 3    Houston Fire Department (HFD)      63166.0     1.0
# 4      General Services Department      56347.0     1.0
# 5    Houston Police Department-HPD      66614.0     1.0
# 6   Public Works & Engineering-PWE      71680.0     1.0
# 7     Houston Airport System (HAS)      42390.0     1.0
# 8   Public Works & Engineering-PWE     107962.0     1.0
# 9     Houston Airport System (HAS)      44616.0     1.0
# 10   Houston Fire Department (HFD)      52644.0     0.0
# 11         Health & Human Services     180416.0     1.0
# 12  Public Works & Engineering-PWE      30347.0     0.0
# 13         Health & Human Services      55269.0     0.0
# 14   Houston Police Department-HPD      77076.0     1.0
# 15   Houston Police Department-HPD          NaN     0.0
# 16   Houston Police Department-HPD          NaN     0.0
# 17   Houston Police Department-HPD      81239.0     1.0
# 18     General Services Department      40581.0     0.0
# 19   Houston Police Department-HPD      66614.0     0.0

# %% [markdown]
# ### Problem 8: Advanced
# <span  style="color:green; font-size:16px"> Programatically Find the 10th occurence of 0 for **`is_max`** and return a DataFrame that ends after the tenth occurence.</span>

# %%
hou_1['occur'] = hou_1.groupby('is_max').cumcount()
hou_1.head(20)
# Out:
#                         DEPARTMENT  BASE_SALARY  is_max  occur
# 0      Municipal Courts Department     121862.0     1.0      0
# 1                          Library      26125.0     1.0      1
# 2    Houston Police Department-HPD      45279.0     1.0      2
# 3    Houston Fire Department (HFD)      63166.0     1.0      3
# 4      General Services Department      56347.0     1.0      4
# 5    Houston Police Department-HPD      66614.0     1.0      5
# 6   Public Works & Engineering-PWE      71680.0     1.0      6
# 7     Houston Airport System (HAS)      42390.0     1.0      7
# 8   Public Works & Engineering-PWE     107962.0     1.0      8
# 9     Houston Airport System (HAS)      44616.0     1.0      9
# 10   Houston Fire Department (HFD)      52644.0     0.0      0
# 11         Health & Human Services     180416.0     1.0     10
# 12  Public Works & Engineering-PWE      30347.0     0.0      1
# 13         Health & Human Services      55269.0     0.0      2
# 14   Houston Police Department-HPD      77076.0     1.0     11
# 15   Houston Police Department-HPD          NaN     0.0      3
# 16   Houston Police Department-HPD          NaN     0.0      4
# 17   Houston Police Department-HPD      81239.0     1.0     12
# 18     General Services Department      40581.0     0.0      5
# 19   Houston Police Department-HPD      66614.0     0.0      6

# %%
idx_10 = hou_1.index[(hou_1.occur == 10) & (hou_1.is_max == 0)][0]

# %%
idx_10
# Out:
# 23

# %%
hou_1.loc[:idx_10]
# Out:
#                         DEPARTMENT  BASE_SALARY  is_max  occur
# 0      Municipal Courts Department     121862.0     1.0      0
# 1                          Library      26125.0     1.0      1
# 2    Houston Police Department-HPD      45279.0     1.0      2
# 3    Houston Fire Department (HFD)      63166.0     1.0      3
# 4      General Services Department      56347.0     1.0      4
# 5    Houston Police Department-HPD      66614.0     1.0      5
# 6   Public Works & Engineering-PWE      71680.0     1.0      6
# 7     Houston Airport System (HAS)      42390.0     1.0      7
# 8   Public Works & Engineering-PWE     107962.0     1.0      8
# 9     Houston Airport System (HAS)      44616.0     1.0      9
# 10   Houston Fire Department (HFD)      52644.0     0.0      0
# 11         Health & Human Services     180416.0     1.0     10
# 12  Public Works & Engineering-PWE      30347.0     0.0      1
# 13         Health & Human Services      55269.0     0.0      2
# 14   Houston Police Department-HPD      77076.0     1.0     11
# 15   Houston Police Department-HPD          NaN     0.0      3
# 16   Houston Police Department-HPD          NaN     0.0      4
# 17   Houston Police Department-HPD      81239.0     1.0     12
# 18     General Services Department      40581.0     0.0      5
# 19   Houston Police Department-HPD      66614.0     0.0      6
# 20  Public Works & Engineering-PWE      61506.0     0.0      7
# 21   Houston Fire Department (HFD)      57815.0     0.0      8
# 22  Public Works & Engineering-PWE      43264.0     0.0      9
# 23   Houston Fire Department (HFD)      55437.0     0.0     10

# %% [markdown]
# ### Problem 9
# <span  style="color:green; font-size:16px"> Write a function that accepts a single argument that will filter **`hou_1`** for a specific department where **`is_max`** is 1. Test your function with departments like 'Library' and 'Public Works & Engineering-PWE'.</span>

# %%
def filter_dep(dep):
    criteria = (hou_1.DEPARTMENT == dep) & (hou_1.is_max == 1)
    return hou_1[criteria]

# %%
filter_dep('Library')
# Out:
#      DEPARTMENT  BASE_SALARY  is_max  occur
# 1       Library      26125.0     1.0      1
# 280     Library      31034.0     1.0     49
# 298     Library      38563.0     1.0     51
# 308     Library      49317.0     1.0     53
# 412     Library      79302.0     1.0     61
# 1165    Library     107763.0     1.0     78

# %%
filter_dep('Public Works & Engineering-PWE')
# Out:
#                           DEPARTMENT  BASE_SALARY  is_max  occur
# 6     Public Works & Engineering-PWE      71680.0     1.0      6
# 8     Public Works & Engineering-PWE     107962.0     1.0      8
# 186   Public Works & Engineering-PWE     110881.0     1.0     39
# 297   Public Works & Engineering-PWE     141948.0     1.0     50
# 1067  Public Works & Engineering-PWE     146141.0     1.0     77
# 1232  Public Works & Engineering-PWE     178331.0     1.0     80

# %% [markdown]
# ### Problem 10
# <span  style="color:green; font-size:16px">A good skill to have is to ask a difficult question for yourself and then answer it. Ask yourself a question that involes grouping and answer it.</span>

# %%
# fill in your answer here

# %% [markdown]
# # 3. Merging Data

# %%
import pandas as pd
import numpy as np

college = pd.read_csv('data/college.csv')
pd.options.display.max_columns = 40

# %% [markdown]
# ### Problem 1
# <span  style="color:green; font-size:16px">Slice the **`college`** dat to get the first 5 rows and 10 columns. Then insert a column called **`SAT_AVG`** that averages the math and verbal SAT scores before the **`SATVRMID`** column.</span>

# %%
# get slice
college_slice = college.iloc[:5, :10]

# get location
insert_num = college_slice.columns.get_loc('SATVRMID')

# get new column values
avg = (college_slice.SATMTMID + college_slice.SATVRMID) / 2

# insert at specific location
college_slice.insert(insert_num, 'SAT_AVG', avg)

# output
college_slice
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SAT_AVG  SATVRMID  SATMTMID  DISTANCEONLY
# 0        0.0         0    422.0     424.0     420.0           0.0
# 1        0.0         0    567.5     570.0     565.0           0.0
# 2        0.0         1      NaN       NaN       NaN           1.0
# 3        0.0         0    592.5     595.0     590.0           0.0
# 4        0.0         0    427.5     425.0     430.0           0.0

# %% [markdown]
# ### Problem 2
# <span  style="color:green; font-size:16px">Read in all three stock csv files and concatenate them horizontally and vertically. Create a hierarchical index that labels each year of data.</span>

# %%
stocks_2014 = pd.read_csv('data/stocks/stocks_2014.csv', index_col='Symbol')
stocks_2015 = pd.read_csv('data/stocks/stocks_2015.csv', index_col='Symbol')
stocks_2016 = pd.read_csv('data/stocks/stocks_2016.csv', index_col='Symbol')

# %%
pd.concat([stocks_2014, stocks_2015, stocks_2016], keys=['2014', '2015', '2016'])
# Out:
#              High  Low  Shares  Short
#      Symbol
# 2014 AAPL     110   95      80    NaN
#      TSLA     130   80      50    NaN
#      WMT       70   55      40    NaN
# 2015 AAPL     140  120      50    NaN
#      GE        40   30     100    NaN
#      IBM       95   75      87    NaN
#      SLB       85   55      20    NaN
#      TXN       23   15     500    NaN
#      TSLA     300  100     100    NaN
# 2016 AAPL     120   90      30   0.20
#      GE        50   35     120   0.10
#      IBM      101   89      90   0.30
#      SLB       90   60      30   0.25
#      TXN       22   17     300   0.05
#      TSLA     245  130     300   0.40
#      WMT       70   55      40   0.10

# %%
pd.concat([stocks_2014, stocks_2015, stocks_2016], keys=['2014', '2015', '2016'], axis=1)
# Out:
#        2014                2015                 2016
#      Shares   Low   High Shares    Low   High Shares  Low High Short
# AAPL   80.0  95.0  110.0   50.0  120.0  140.0     30   90  120  0.20
# GE      NaN   NaN    NaN  100.0   30.0   40.0    120   35   50  0.10
# IBM     NaN   NaN    NaN   87.0   75.0   95.0     90   89  101  0.30
# SLB     NaN   NaN    NaN   20.0   55.0   85.0     30   60   90  0.25
# TSLA   50.0  80.0  130.0  100.0  100.0  300.0    300  130  245  0.40
# TXN     NaN   NaN    NaN  500.0   15.0   23.0    300   17   22  0.05
# WMT    40.0  55.0   70.0    NaN    NaN    NaN     40   55   70  0.10

# %% [markdown]
# ### Problem 3
# <span  style="color:green; font-size:16px">Take a look at the DataFrame below. Count the total appearances of each letter.</span>

# %%
from string import ascii_lowercase
np.random.seed(1)
df = pd.DataFrame(np.random.choice(list(ascii_lowercase), (20,5), replace=True), 
                  columns = ['col1', 'col2', 'col3', 'col4', 'col5'])

df
# Out:
#    col1 col2 col3 col4 col5
# 0     f    l    m    i    j
# 1     l    f    p    a    q
# 2     b    m    h    n    g
# 3     z    s    u    f    s
# 4     u    l    k    o    s
# 5     e    x    x    j    r
# 6     x    a    w    n    j
# 7     j    h    w    z    b
# 8     a    r    i    y    n
# 9     t    p    k    z    i
# 10    h    d    g    v    r
# 11    z    d    e    y    r
# 12    l    m    u    q    n
# 13    t    j    s    p    a
# 14    e    z    p    c    x
# 15    h    z    i    w    j
# 16    d    h    x    e    f
# 17    z    t    g    i    a
# 18    c    k    x    p    p
# 19    x    z    h    t    k

# %%
# make one long series and then use value_counts
pd.concat([df.col1, df.col2, df.col3, df.col4, df.col5]).value_counts()
# Out:
# z    8
# x    7
# h    6
# p    6
# j    6
# a    5
# i    5
# r    4
# e    4
# k    4
# f    4
# t    4
# l    4
# n    4
# s    4
# g    3
# u    3
# w    3
# d    3
# m    3
# b    2
# c    2
# q    2
# y    2
# v    1
# o    1
# dtype: int64

# %% [markdown]
# ### Problem 4
# <span  style="color:green; font-size:16px">Each Series below represents the amount of TV watched for each sport. Combine all Series so that each column represents a different labeled day. Fill in the missing values with 0. Save it to **`df_sports`**</span>

# %%
day1 = pd.Series({'soccer':45, 'basketball':30, 'tennis':10})
day2 = pd.Series({'soccer':55, 'basketball':10, 'bowling':10, 'volleyball':30})
day3 = pd.Series({'soccer':15, 'basketball':20, 'volleyball':40})
day4 = pd.Series({'bowling':100, 'volleyball':20, 'basketball':1})

# %%
df_sports = pd.concat([day1, day2, day3, day4],axis=1, keys=['day1', 'day2', 'day3', 'day4'])

df_sports
# Out:
#             day1  day2  day3   day4
# basketball  30.0  10.0  20.0    1.0
# bowling      NaN  10.0   NaN  100.0
# soccer      45.0  55.0  15.0    NaN
# tennis      10.0   NaN   NaN    NaN
# volleyball   NaN  30.0  40.0   20.0

# %% [markdown]
# ### Problem 5
# <span  style="color:green; font-size:16px">Use **`df_sports`** to find the total TV watched per sport for all the days and also the total amount of TV watched per day. Sort both results from greatest to least.</span>

# %%
df_sports.sum().sort_values(ascending=False)
# Out:
# day4    121.0
# day2    105.0
# day1     85.0
# day3     75.0
# dtype: float64

# %%
df_sports.sum(axis=1).sort_values(ascending=False)
# Out:
# soccer        115.0
# bowling       110.0
# volleyball     90.0
# basketball     61.0
# tennis         10.0
# dtype: float64

# %% [markdown]
# ### Problem 6
# <span  style="color:green; font-size:16px">Look up the method **`isnull`** and count the number of nulls per sport.</span>

# %%
df_sports.isnull().sum(axis=1)
# Out:
# basketball    0
# bowling       2
# soccer        1
# tennis        3
# volleyball    1
# dtype: int64

# %% [markdown]
# ### Problem 7
# <span  style="color:green; font-size:16px">Combine all Series again, keeping only the sports that have no missing values for any days.</span>

# %%
pd.concat([day1, day2, day3, day4], axis=1, keys=['day1', 'day2', 'day3', 'day4'], join='inner')
# Out:
#             day1  day2  day3  day4
# basketball    30    10    20     1

# %%
df_null_summary = df.isnull().mean().

# %%
df_1 = pd.concat([df.isnull().sum(), df.isnull().mean()], axis=1, keys=['Missing Values', 'Percentage'])

# %%
df.columns = pd.MultiIndex.from_arrays([range(len(df.columns)), df.columns])

# %%
pd.concat([df.isnull().sum(), df.isnull().mean()], axis=1, keys=['Missing Values', 'Percentage'])
# Out:
#         Missing Values  Percentage
# 0 col1               0         0.0
# 1 col2               0         0.0
# 2 col3               0         0.0
# 3 col4               0         0.0
# 4 col5               0         0.0

# %%
df[df.columns[df.isnull().mean() < .4]]
# Out:
#       0    1    2    3    4
#    col1 col2 col3 col4 col5
# 0     f    l    m    i    j
# 1     l    f    p    a    q
# 2     b    m    h    n    g
# 3     z    s    u    f    s
# 4     u    l    k    o    s
# 5     e    x    x    j    r
# 6     x    a    w    n    j
# 7     j    h    w    z    b
# 8     a    r    i    y    n
# 9     t    p    k    z    i
# 10    h    d    g    v    r
# 11    z    d    e    y    r
# 12    l    m    u    q    n
# 13    t    j    s    p    a
# 14    e    z    p    c    x
# 15    h    z    i    w    j
# 16    d    h    x    e    f
# 17    z    t    g    i    a
# 18    c    k    x    p    p
# 19    x    z    h    t    k

# %% [markdown]
# # 4. Relational Databases

# %% [markdown]
# ### Problem 1
# <span  style="color:green; font-size:16px">How many media types does each track have? Answer this by looking at the data diagram and then programmatically.</span>

# %%
# the diagram indicates each track has one and only one media type.
tracks = pd.read_csv('data/chinook/tracks.csv')
media = pd.read_csv('data/chinook/media_types.csv')

# %%
track_media = tracks.merge(media, on='MediaTypeId')

# %%
# if max repetitions of trackid is one then it is one to one
track_media['TrackId'].value_counts().head(10)
# Out:
# 2047    1
# 2624    1
# 597     1
# 2644    1
# 593     1
# 2640    1
# 589     1
# 2636    1
# 585     1
# 2632    1
# Name: TrackId, dtype: int64

# %% [markdown]
# ### Problem 2
# <span  style="color:green; font-size:16px">Which track has sold the most copies?</span>

# %%
invoice_items = pd.read_csv('data/chinook/invoice_items.csv')

# %%
tracks_invoice_items = tracks.merge(invoice_items, on='TrackId')

# %%
# Find track Id that has highest count
track_quantity = tracks_invoice_items.groupby('TrackId')['Quantity'].sum().sort_values(ascending=False)

track_quantity.head()
# Out:
# TrackId
# 2031    38
# 184     36
# 1888    36
# 925     36
# 2352    36
# Name: Quantity, dtype: int64

# %%
tracks_invoice_items[tracks_invoice_items.TrackId == 2031]
# Out:
#       TrackId                    Name  AlbumId  MediaTypeId  GenreId Composer  \
# 1318     2031  Nossa Gente (Avisa Là)      166            1        7      NaN
# 1319     2031  Nossa Gente (Avisa Là)      166            1        7      NaN
#
#       Milliseconds    Bytes  UnitPrice_x  InvoiceLineId  InvoiceId  \
# 1318        188212  6233201         1.25            907        166
# 1319        188212  6233201         1.25           2058        380
#
#       UnitPrice_y  Quantity
# 1318         1.25        19
# 1319         1.25        19

# %% [markdown]
# ### Problem 3
# <span  style="color:green; font-size:16px">Which playlist has the most tracks?</span>

# %%
# your code here

# %%
playlists = pd.read_csv('data/chinook/playlists.csv')
playlist_tracks = pd.read_csv('data/chinook/playlist_track.csv')

# %%
playlist_trackid = playlists.merge(playlist_tracks, on = 'PlaylistId')
playlist_trackid.head(10)
# Out:
#    PlaylistId   Name  TrackId
# 0           1  Music     3402
# 1           1  Music     3389
# 2           1  Music     3390
# 3           1  Music     3391
# 4           1  Music     3392
# 5           1  Music     3393
# 6           1  Music     3394
# 7           1  Music     3395
# 8           1  Music     3396
# 9           1  Music     3397

# %%
playlist_trackid['Name'].value_counts()
# Out:
# Music                         6580
# 90’s Music                    1477
# TV Shows                       426
# Classical                       75
# Brazilian Music                 39
# Heavy Metal Classic             26
# Classical 101 - Next Steps      25
# Classical 101 - Deep Cuts       25
# Classical 101 - The Basics      25
# Grunge                          15
# On-The-Go 1                      1
# Music Videos                     1
# Name: Name, dtype: int64

# %% [markdown]
# ### Problem 4
# <span  style="color:green; font-size:16px">Which playlist, that has at least 15 tracks has on average the most expensive tracks?</span>

# %%
playlist_track_price = playlist_trackid.merge(tracks[['TrackId', 'UnitPrice']], on='TrackId')

# %%
playlist_track_price_filtered = playlist_track_price.groupby('Name').filter(lambda x: x.size >= 15)

# %%
playlist_track_price_filtered.groupby('Name')['UnitPrice'].mean().sort_values(ascending=False)
# Out:
# Name
# Brazilian Music               1.021795
# TV Shows                      1.001455
# Music                         0.997860
# Classical 101 - Deep Cuts     0.995600
# Grunge                        0.995333
# 90’s Music                    0.993521
# Heavy Metal Classic           0.987692
# Classical                     0.952933
# Classical 101 - The Basics    0.937200
# Classical 101 - Next Steps    0.926000
# Name: UnitPrice, dtype: float64

# %% [markdown]
# ### Problem 5: Advanced
# <span  style="color:green; font-size:16px">Find the most sold genre per country.</span>

# %%
customers = pd.read_csv('data/chinook/customers.csv')
invoices = pd.read_csv('data/chinook/invoices.csv')

# %%
inv_cust =  invoices.merge(customers, on='CustomerId')

# %%
inv_cust.head()
# Out:
#    InvoiceId  CustomerId          InvoiceDate           BillingAddress  \
# 0          1           2  2009-01-01 00:00:00  Theodor-Heuss-Straße 34
# 1         12           2  2009-02-11 00:00:00  Theodor-Heuss-Straße 34
# 2         67           2  2009-10-12 00:00:00  Theodor-Heuss-Straße 34
# 3        196           2  2011-05-19 00:00:00  Theodor-Heuss-Straße 34
# 4        219           2  2011-08-21 00:00:00  Theodor-Heuss-Straße 34
#
#   BillingCity BillingState BillingCountry BillingPostalCode  Total FirstName  \
# 0   Stuttgart          NaN        Germany             70174   1.98    Leonie
# 1   Stuttgart          NaN        Germany             70174  13.86    Leonie
# 2   Stuttgart          NaN        Germany             70174   8.91    Leonie
# 3   Stuttgart          NaN        Germany             70174   1.98    Leonie
# 4   Stuttgart          NaN        Germany             70174   3.96    Leonie
#
#   LastName Company                  Address       City State  Country  \
# 0   Köhler     NaN  Theodor-Heuss-Straße 34  Stuttgart   NaN  Germany
# 1   Köhler     NaN  Theodor-Heuss-Straße 34  Stuttgart   NaN  Germany
# 2   Köhler     NaN  Theodor-Heuss-Straße 34  Stuttgart   NaN  Germany
# 3   Köhler     NaN  Theodor-Heuss-Straße 34  Stuttgart   NaN  Germany
# 4   Köhler     NaN  Theodor-Heuss-Straße 34  Stuttgart   NaN  Germany
#
#   PostalCode             Phone  Fax                  Email  SupportRepId
# 0      70174  +49 0711 2842222  NaN  leonekohler@surfeu.de             5
# 1      70174  +49 0711 2842222  NaN  leonekohler@surfeu.de             5
# 2      70174  +49 0711 2842222  NaN  leonekohler@surfeu.de             5
# 3      70174  +49 0711 2842222  NaN  leonekohler@surfeu.de             5
# 4      70174  +49 0711 2842222  NaN  leonekohler@surfeu.de             5

# %%
## Select only important columns
inv_cust = inv_cust[['InvoiceId', 'Country']]

# %%
inv_cust_quant = inv_cust.merge(invoice_items, on='InvoiceId')
inv_cust_quant.head(10)
# Out:
#    InvoiceId  Country  InvoiceLineId  TrackId  UnitPrice  Quantity
# 0          1  Germany              1        2       1.25        15
# 1          1  Germany              2        4       1.25         1
# 2         12  Germany             60      331       0.99        19
# 3         12  Germany             61      340       0.75         2
# 4         12  Germany             62      349       0.99        11
# 5         12  Germany             63      358       0.99         1
# 6         12  Germany             64      367       0.99         8
# 7         12  Germany             65      376       0.99         1
# 8         12  Germany             66      385       0.75        18
# 9         12  Germany             67      394       0.99        15

# %%
# keep only relevant columns
inv_cust_quant = inv_cust_quant[['TrackId', 'Country', 'Quantity']]

# %%
inv_cust_quant_track = inv_cust_quant.merge(tracks, on='TrackId')

# %%
inv_cust_quant_track.head()
# Out:
#    TrackId  Country  Quantity                Name  AlbumId  MediaTypeId  \
# 0        2  Germany        15   Balls to the Wall        2            2
# 1        2   Canada         4   Balls to the Wall        2            2
# 2        4  Germany         1   Restless and Wild        3            2
# 3      331  Germany        19           Lavadeira       29            1
# 4      340  Germany         2  Dazed and Confused       30            1
#
#    GenreId                                           Composer  Milliseconds  \
# 0        1                                                NaN        342562
# 1        1                                                NaN        342562
# 2        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 3        9       Do Vale, Valverde/Gal Oliveira/Luciano Pinto        214256
# 4        1                                         Jimmy Page        401920
#
#       Bytes  UnitPrice
# 0   5510424       1.25
# 1   5510424       1.25
# 2   4331779       1.25
# 3   7254147       0.99
# 4  13035765       0.75

# %%
# cut columns again
inv_cust_quant_track = inv_cust_quant_track[['Country', 'Quantity', 'GenreId']]

# %%
inv_cust_quant_track.shape
# Out:
# (2240, 3)

# %%
inv_cust_quant_track.head()
# Out:
#    Country  Quantity  GenreId
# 0  Germany        15        1
# 1   Canada         4        1
# 2  Germany         1        1
# 3  Germany        19        9
# 4  Germany         2        1

# %%
genre = pd.read_csv('data/chinook/genres.csv')

# %%
# finally append genre
country_genre = inv_cust_quant_track.merge(genre, on='GenreId')

country_genre.head()
# Out:
#    Country  Quantity  GenreId  Name
# 0  Germany        15        1  Rock
# 1   Canada         4        1  Rock
# 2  Germany         1        1  Rock
# 3  Germany         2        1  Rock
# 4  Germany        11        1  Rock

# %%
final_country_genre = country_genre.groupby(['Country', 'Name'], as_index=False)['Quantity'].sum()

# %%
final_country_genre.head()
# Out:
#      Country                Name  Quantity
# 0  Argentina  Alternative & Punk       106
# 1  Argentina      Easy Listening        25
# 2  Argentina                Jazz        28
# 3  Argentina               Latin        79
# 4  Argentina               Metal        62

# %%
final_country_genre_sorted = final_country_genre.sort_values(['Country', 'Quantity'], ascending=[True, False])

# %%
final_country_genre_sorted.head(15)
# Out:
#       Country                Name  Quantity
# 0   Argentina  Alternative & Punk       106
# 3   Argentina               Latin        79
# 5   Argentina                Rock        69
# 4   Argentina               Metal        62
# 2   Argentina                Jazz        28
# 1   Argentina      Easy Listening        25
# 6   Argentina          Soundtrack         5
# 12  Australia                Rock       226
# 10  Australia               Metal        79
# 8   Australia         Heavy Metal        48
# 11  Australia              Reggae        17
# 9   Australia               Latin         5
# 7   Australia               Blues         3
# 20    Austria                Rock        97
# 17    Austria               Metal        65

# %%
final_country_genre_sorted.groupby('Country').first()
# Out:
#                               Name  Quantity
# Country
# Argentina       Alternative & Punk       106
# Australia                     Rock       226
# Austria                       Rock        97
# Belgium                       Rock       194
# Brazil                        Rock       769
# Canada                        Rock      1086
# Chile                        Latin        98
# Czech Republic                Rock       275
# Denmark                       Rock       214
# Finland                       Rock       167
# France                        Rock       571
# Germany                       Rock       562
# Hungary                       Rock       115
# India                         Rock       260
# Ireland                   TV Shows        82
# Italy                         Rock       138
# Netherlands                   Rock       174
# Norway                        Rock       173
# Poland                        Rock       232
# Portugal                      Rock       319
# Spain                         Rock       221
# Sweden                       Latin       105
# USA                           Rock      1429
# United Kingdom                Rock       341

# %% [markdown]
# ### Problem 6
# <span  style="color:green; font-size:16px">Find the name and email of each employee's boss. When the left table and right table have different column names for the joining key use the arguments **`left_on`** and **`right_on`**. Make use of the suffix arguments to better label the merged data. Be sure to include employees that don't have bosses. This is called a recursive relationship.</span>

# %%
employees = pd.read_csv('data/chinook/employees.csv')

# %%
employee_boss = employees.merge(employees, left_on='ReportsTo', right_on='EmployeeId', how='left', suffixes=('_Emp', '_Boss'))

# %%
employee_boss
# Out:
#    EmployeeId_Emp LastName_Emp FirstName_Emp            Title_Emp  \
# 0               1        Adams        Andrew      General Manager
# 1               2      Edwards         Nancy        Sales Manager
# 2               3      Peacock          Jane  Sales Support Agent
# 3               4         Park      Margaret  Sales Support Agent
# 4               5      Johnson         Steve  Sales Support Agent
# 5               6     Mitchell       Michael           IT Manager
# 6               7         King        Robert             IT Staff
# 7               8     Callahan         Laura             IT Staff
#
#    ReportsTo_Emp        BirthDate_Emp         HireDate_Emp  \
# 0            NaN  1962-02-18 00:00:00  2002-08-14 00:00:00
# 1            1.0  1958-12-08 00:00:00  2002-05-01 00:00:00
# 2            2.0  1973-08-29 00:00:00  2002-04-01 00:00:00
# 3            2.0  1947-09-19 00:00:00  2003-05-03 00:00:00
# 4            2.0  1965-03-03 00:00:00  2003-10-17 00:00:00
# 5            1.0  1973-07-01 00:00:00  2003-10-17 00:00:00
# 6            6.0  1970-05-29 00:00:00  2004-01-02 00:00:00
# 7            6.0  1968-01-09 00:00:00  2004-03-04 00:00:00
#
#                    Address_Emp    City_Emp State_Emp Country_Emp  \
# 0          11120 Jasper Ave NW    Edmonton        AB      Canada
# 1                 825 8 Ave SW     Calgary        AB      Canada
# 2                1111 6 Ave SW     Calgary        AB      Canada
# 3             683 10 Street SW     Calgary        AB      Canada
# 4                 7727B 41 Ave     Calgary        AB      Canada
# 5         5827 Bowness Road NW     Calgary        AB      Canada
# 6  590 Columbia Boulevard West  Lethbridge        AB      Canada
# 7                  923 7 ST NW  Lethbridge        AB      Canada
#
#   PostalCode_Emp          Phone_Emp            Fax_Emp  \
# 0        T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1        T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2        T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3        T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4        T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
# 5        T3B 0C5  +1 (403) 246-9887  +1 (403) 246-9899
# 6        T1K 5N8  +1 (403) 456-9986  +1 (403) 456-8485
# 7        T1H 1Y8  +1 (403) 467-3351  +1 (403) 467-8772
#
#                   Email_Emp  EmployeeId_Boss LastName_Boss FirstName_Boss  \
# 0    andrew@chinookcorp.com              NaN           NaN            NaN
# 1     nancy@chinookcorp.com              1.0         Adams         Andrew
# 2      jane@chinookcorp.com              2.0       Edwards          Nancy
# 3  margaret@chinookcorp.com              2.0       Edwards          Nancy
# 4     steve@chinookcorp.com              2.0       Edwards          Nancy
# 5   michael@chinookcorp.com              1.0         Adams         Andrew
# 6    robert@chinookcorp.com              6.0      Mitchell        Michael
# 7     laura@chinookcorp.com              6.0      Mitchell        Michael
#
#         Title_Boss  ReportsTo_Boss       BirthDate_Boss        HireDate_Boss  \
# 0              NaN             NaN                  NaN                  NaN
# 1  General Manager             NaN  1962-02-18 00:00:00  2002-08-14 00:00:00
# 2    Sales Manager             1.0  1958-12-08 00:00:00  2002-05-01 00:00:00
# 3    Sales Manager             1.0  1958-12-08 00:00:00  2002-05-01 00:00:00
# 4    Sales Manager             1.0  1958-12-08 00:00:00  2002-05-01 00:00:00
# 5  General Manager             NaN  1962-02-18 00:00:00  2002-08-14 00:00:00
# 6       IT Manager             1.0  1973-07-01 00:00:00  2003-10-17 00:00:00
# 7       IT Manager             1.0  1973-07-01 00:00:00  2003-10-17 00:00:00
#
#            Address_Boss City_Boss State_Boss Country_Boss PostalCode_Boss  \
# 0                   NaN       NaN        NaN          NaN             NaN
# 1   11120 Jasper Ave NW  Edmonton         AB       Canada         T5K 2N1
# 2          825 8 Ave SW   Calgary         AB       Canada         T2P 2T3
# 3          825 8 Ave SW   Calgary         AB       Canada         T2P 2T3
# 4          825 8 Ave SW   Calgary         AB       Canada         T2P 2T3
# 5   11120 Jasper Ave NW  Edmonton         AB       Canada         T5K 2N1
# 6  5827 Bowness Road NW   Calgary         AB       Canada         T3B 0C5
# 7  5827 Bowness Road NW   Calgary         AB       Canada         T3B 0C5
#
#           Phone_Boss           Fax_Boss               Email_Boss
# 0                NaN                NaN                      NaN
# 1  +1 (780) 428-9482  +1 (780) 428-3457   andrew@chinookcorp.com
# 2  +1 (403) 262-3443  +1 (403) 262-3322    nancy@chinookcorp.com
# 3  +1 (403) 262-3443  +1 (403) 262-3322    nancy@chinookcorp.com
# 4  +1 (403) 262-3443  +1 (403) 262-3322    nancy@chinookcorp.com
# 5  +1 (780) 428-9482  +1 (780) 428-3457   andrew@chinookcorp.com
# 6  +1 (403) 246-9887  +1 (403) 246-9899  michael@chinookcorp.com
# 7  +1 (403) 246-9887  +1 (403) 246-9899  michael@chinookcorp.com

# %%
## select important columns for boss
employee_boss[['LastName_Emp', 'FirstName_Emp', 'Title_Emp', 'ReportsTo_Emp',
              'LastName_Boss', 'FirstName_Boss', 'Title_Boss', 'ReportsTo_Boss', 'Email_Boss']]
# Out:
#   LastName_Emp FirstName_Emp            Title_Emp  ReportsTo_Emp  \
# 0        Adams        Andrew      General Manager            NaN
# 1      Edwards         Nancy        Sales Manager            1.0
# 2      Peacock          Jane  Sales Support Agent            2.0
# 3         Park      Margaret  Sales Support Agent            2.0
# 4      Johnson         Steve  Sales Support Agent            2.0
# 5     Mitchell       Michael           IT Manager            1.0
# 6         King        Robert             IT Staff            6.0
# 7     Callahan         Laura             IT Staff            6.0
#
#   LastName_Boss FirstName_Boss       Title_Boss  ReportsTo_Boss  \
# 0           NaN            NaN              NaN             NaN
# 1         Adams         Andrew  General Manager             NaN
# 2       Edwards          Nancy    Sales Manager             1.0
# 3       Edwards          Nancy    Sales Manager             1.0
# 4       Edwards          Nancy    Sales Manager             1.0
# 5         Adams         Andrew  General Manager             NaN
# 6      Mitchell        Michael       IT Manager             1.0
# 7      Mitchell        Michael       IT Manager             1.0
#
#                 Email_Boss
# 0                      NaN
# 1   andrew@chinookcorp.com
# 2    nancy@chinookcorp.com
# 3    nancy@chinookcorp.com
# 4    nancy@chinookcorp.com
# 5   andrew@chinookcorp.com
# 6  michael@chinookcorp.com
# 7  michael@chinookcorp.com

# %% [markdown]
# ### Problem 7
# <span  style="color:green; font-size:16px">Which artists have the longest tracks on average? Return answer in minutes.</span>

# %%
artists = pd.read_csv('data/chinook/artists.csv')
albums = pd.read_csv('data/chinook/albums.csv')
tracks = pd.read_csv('data/chinook/tracks.csv')

# %%
artist_album = pd.merge(artists, albums, on='ArtistId')
artist_album.head(10)
# Out:
#    ArtistId                  Name  AlbumId  \
# 0         1                 AC/DC        1
# 1         1                 AC/DC        4
# 2         2                Accept        2
# 3         2                Accept        3
# 4         3             Aerosmith        5
# 5         4     Alanis Morissette        6
# 6         5       Alice In Chains        7
# 7         6  Antônio Carlos Jobim        8
# 8         6  Antônio Carlos Jobim       34
# 9         7          Apocalyptica        9
#
#                                    Title
# 0  For Those About To Rock We Salute You
# 1                      Let There Be Rock
# 2                      Balls to the Wall
# 3                      Restless and Wild
# 4                               Big Ones
# 5                     Jagged Little Pill
# 6                               Facelift
# 7                         Warner 25 Anos
# 8                 Chill: Brazil (Disc 2)
# 9         Plays Metallica By Four Cellos

# %%
# rename 'Name' to something more descriptive
artist_album = artist_album.rename(columns={'Name':'ArtistName'})

# %%
artist_time = artist_album.merge(tracks[['AlbumId', 'Name', 'Milliseconds']], on='AlbumId')

# %%
artist_time.head(10)
# Out:
#    ArtistId ArtistName  AlbumId                                  Title  \
# 0         1      AC/DC        1  For Those About To Rock We Salute You
# 1         1      AC/DC        1  For Those About To Rock We Salute You
# 2         1      AC/DC        1  For Those About To Rock We Salute You
# 3         1      AC/DC        1  For Those About To Rock We Salute You
# 4         1      AC/DC        1  For Those About To Rock We Salute You
# 5         1      AC/DC        1  For Those About To Rock We Salute You
# 6         1      AC/DC        1  For Those About To Rock We Salute You
# 7         1      AC/DC        1  For Those About To Rock We Salute You
# 8         1      AC/DC        1  For Those About To Rock We Salute You
# 9         1      AC/DC        1  For Those About To Rock We Salute You
#
#                                       Name  Milliseconds
# 0  For Those About To Rock (We Salute You)        343719
# 1                    Put The Finger On You        205662
# 2                          Let's Get It Up        233926
# 3                         Inject The Venom        210834
# 4                               Snowballed        203102
# 5                               Evil Walks        263497
# 6                                   C.O.D.        199836
# 7                       Breaking The Rules        263288
# 8                 Night Of The Long Knives        205688
# 9                               Spellbound        270863

# %%
# get average time per artist
artist_time_summary = artist_time.groupby('ArtistName')['Milliseconds'].mean() / 60000

# %%
artist_time_summary.sort_values(ascending=False).head(10)
# Out:
# ArtistName
# Battlestar Galactica (Classic)               48.759567
# Battlestar Galactica                         46.174400
# Heroes                                       43.319033
# Lost                                         43.166400
# Aquaman                                      41.409450
# The Office                                   23.562400
# Leonard Bernstein & New York Philharmonic     9.941983
# Scholars Baroque Ensemble                     9.700483
# Terry Bozzio, Tony Levin & Steve Stevens      9.596500
# Adrian Leaper & Doreen de Feis                9.458233
# Name: Milliseconds, dtype: float64

# %% [markdown]
# # Case Study - Counting Pandas Solutions

# %%
import pandas as pd
api_tables = pd.read_html('http://pandas.pydata.org/pandas-docs/stable/api.html')

# %% [markdown]
# ## Problem 1
# <span  style="color:green; font-size:16px"> Writing a new for loop every time we want to count a new word in our dataset is cumbersome. Can you write a function that accepts the parameter **word** and returns the count of this word if it appears as in the pandas API as a functions/methods/attributes. Count a few words with it like DataFrame or MultiIndex</span>

# %%
def count_functionality(word):
    return sum([table[0].str.contains(word).sum() for table in api_tables])

# %%
count_functionality('Series'), count_functionality('DataFrame'), count_functionality('MultiIndex')
# Out:
# (283, 225, 11)

# %% [markdown]
# ## Problem 2
# <span  style="color:green; font-size:16px">Define a new function by modifying the above function slightly to have it return a list of all the methods</span>

# %%
def list_functionality(word):
    return_list = []
    for table in api_tables:
        s = table[0] # get first column
        cur_list = s[s.str.contains(word)].tolist() # get only items with word in it and convert to list
        return_list.extend(cur_list)
    return return_list

# %%
# these methods should look very familiar from the builtin python str methods
str_series = list_functionality('Series.str')
str_series
# Out:
# ['Series.strides',
#  'Series.str.capitalize()',
#  'Series.str.cat([others,\xa0sep,\xa0na_rep])',
#  'Series.str.center(width[,\xa0fillchar])',
#  'Series.str.contains(pat[,\xa0case,\xa0flags,\xa0na,\xa0...])',
#  'Series.str.count(pat[,\xa0flags])',
#  'Series.str.decode(encoding[,\xa0errors])',
#  'Series.str.encode(encoding[,\xa0errors])',
#  'Series.str.endswith(pat[,\xa0na])',
#  'Series.str.extract(pat[,\xa0flags,\xa0expand])',
#  'Series.str.extractall(pat[,\xa0flags])',
#  'Series.str.find(sub[,\xa0start,\xa0end])',
#  'Series.str.findall(pat[,\xa0flags])',
#  'Series.str.get(i)',
#  'Series.str.index(sub[,\xa0start,\xa0end])',
#  'Series.str.join(sep)',
#  'Series.str.len()',
#  'Series.str.ljust(width[,\xa0fillchar])',
#  'Series.str.lower()',
#  'Series.str.lstrip([to_strip])',
#  'Series.str.match(pat[,\xa0case,\xa0flags,\xa0na,\xa0...])',
#  'Series.str.normalize(form)',
#  'Series.str.pad(width[,\xa0side,\xa0fillchar])',
#  'Series.str.partition([pat,\xa0expand])',
#  'Series.str.repeat(repeats)',
#  'Series.str.replace(pat,\xa0repl[,\xa0n,\xa0case,\xa0flags])',
#  'Series.str.rfind(sub[,\xa0start,\xa0end])',
#  'Series.str.rindex(sub[,\xa0start,\xa0end])',
#  'Series.str.rjust(width[,\xa0fillchar])',
#  'Series.str.rpartition([pat,\xa0expand])',
#  'Series.str.rstrip([to_strip])',
#  'Series.str.slice([start,\xa0stop,\xa0step])',
#  'Series.str.slice_replace([start,\xa0stop,\xa0repl])',
#  'Series.str.split([pat,\xa0n,\xa0expand])',
#  'Series.str.rsplit([pat,\xa0n,\xa0expand])',
#  'Series.str.startswith(pat[,\xa0na])',
#  'Series.str.strip([to_strip])',
#  'Series.str.swapcase()',
#  'Series.str.title()',
#  'Series.str.translate(table[,\xa0deletechars])',
#  'Series.str.upper()',
#  'Series.str.wrap(width,\xa0\\*\\*kwargs)',
#  'Series.str.zfill(width)',
#  'Series.str.isalnum()',
#  'Series.str.isalpha()',
#  'Series.str.isdigit()',
#  'Series.str.isspace()',
#  'Series.str.islower()',
#  'Series.str.isupper()',
#  'Series.str.istitle()',
#  'Series.str.isnumeric()',
#  'Series.str.isdecimal()',
#  'Series.str.get_dummies([sep])']

# %% [markdown]
# ## Problem 3
# <span  style="color:green; font-size:16px">Explore several of the Series `.str` methods that you should now have captured in a list on one of the API reference tables to get </span>

# %%
s = api_tables[44][0]

# %%
s.str.swapcase()
# Out:
# 0      sERIES.FROM_CSV(PATH[, SEP, PARSE_DATES, ...])
# 1                              sERIES.TO_PICKLE(PATH)
# 2      sERIES.TO_CSV([PATH, INDEX, SEP, NA_REP, ...])
# 3                                    sERIES.TO_DICT()
# 4                             sERIES.TO_FRAME([NAME])
# 5                                  sERIES.TO_XARRAY()
# 6         sERIES.TO_HDF(PATH_OR_BUF, KEY, \*\*KWARGS)
# 7     sERIES.TO_SQL(NAME, CON[, FLAVOR, SCHEMA, ...])
# 8          sERIES.TO_MSGPACK([PATH_OR_BUF, ENCODING])
# 9          sERIES.TO_JSON([PATH_OR_BUF, ORIENT, ...])
# 10               sERIES.TO_SPARSE([KIND, FILL_VALUE])
# 11                                  sERIES.TO_DENSE()
# 12               sERIES.TO_STRING([BUF, NA_REP, ...])
# 13                  sERIES.TO_CLIPBOARD([EXCEL, SEP])
# Name: 0, dtype: object

# %%
s.str.split() # split each element by blank space
# Out:
# 0     [Series.from_csv(path[,, sep,, parse_dates,, ....
# 1                              [Series.to_pickle(path)]
# 2     [Series.to_csv([path,, index,, sep,, na_rep,, ...
# 3                                    [Series.to_dict()]
# 4                             [Series.to_frame([name])]
# 5                                  [Series.to_xarray()]
# 6       [Series.to_hdf(path_or_buf,, key,, \*\*kwargs)]
# 7     [Series.to_sql(name,, con[,, flavor,, schema,,...
# 8         [Series.to_msgpack([path_or_buf,, encoding])]
# 9        [Series.to_json([path_or_buf,, orient,, ...])]
# 10              [Series.to_sparse([kind,, fill_value])]
# 11                                  [Series.to_dense()]
# 12             [Series.to_string([buf,, na_rep,, ...])]
# 13                 [Series.to_clipboard([excel,, sep])]
# Name: 0, dtype: object

# %%
# chain another str method and get the second element in the split list
s.str.split().str.get(1)
# Out:
# 0             sep,
# 1              NaN
# 2           index,
# 3              NaN
# 4              NaN
# 5              NaN
# 6             key,
# 7            con[,
# 8       encoding])
# 9          orient,
# 10    fill_value])
# 11             NaN
# 12         na_rep,
# 13           sep])
# Name: 0, dtype: object

# %% [markdown]
# ## Problem 4
# <span  style="color:green; font-size:16px">Lets get some 'live' data.</span>
# 1. Naviate to [real clear politics](http://www.realclearpolitics.com)
# 1. In the top left corner of the page, hover over the polls section and click on Clinton vs Trump
# 1. use pandas read_html to read in that full table at the bottom of the page and display it here in the notebook
# 1. use the header parameter to find the correct header instead of the default numbers
# 1. Inspect the info to make sure the clinton and trump data types are float64
# 1. add a column that calculates the difference of trump vs clinton
# 1. sort the dataframe by this newly created column
# 1. Do you see anything suspicious about the polls where Trump is leading?

# %%
rcp_tables = pd.read_html('http://www.realclearpolitics.com/epolls/2016/president/us/general_election_trump_vs_clinton-5491.html', header=0)

# %%
len(rcp_tables)
# Out:
# 3

# %%
rcp_final = rcp_tables[2]

# %%
rcp_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 7 columns):
# Poll           261 non-null object
# Date           261 non-null object
# Sample         261 non-null object
# MoE            261 non-null object
# Clinton (D)    261 non-null float64
# Trump (R)      261 non-null float64
# Spread         261 non-null object
# dtypes: float64(2), object(5)
# memory usage: 14.4+ KB

# %%
rcp_final['diff'] = rcp_final['Clinton (D)'] - rcp_final['Trump (R)']

# %%
rcp_final.head(20)
# Out:
#                                      Poll           Date    Sample  MoE  \
# 0                           Final Results             --        --   --
# 1                             RCP Average    11/1 - 11/7        --   --
# 2                      BloombergBloomberg    11/4 - 11/6    799 LV  3.5
# 3      IBD/TIPP TrackingIBD/TIPP Tracking    11/4 - 11/7   1107 LV  3.1
# 4               Economist/YouGovEconomist    11/4 - 11/7   3669 LV   --
# 5           LA Times/USC TrackingLA Times    11/1 - 11/7   2935 LV  4.5
# 6   ABC/Wash Post TrackingABC/WP Tracking    11/3 - 11/6   2220 LV  2.5
# 7                        FOX NewsFOX News    11/3 - 11/6   1295 LV  2.5
# 8                        MonmouthMonmouth    11/3 - 11/6    748 LV  3.6
# 9           NBC News/Wall St. JrnlNBC/WSJ    11/3 - 11/5   1282 LV  2.7
# 10                       CBS NewsCBS News    11/2 - 11/6   1426 LV  3.0
# 11                   Reuters/IpsosReuters    11/2 - 11/6   2196 LV  2.3
# 12              McClatchy/MaristMcClatchy    11/1 - 11/3    940 LV  3.2
# 13                       FOX NewsFOX News    11/1 - 11/3   1107 LV  3.0
# 14                    NBC News/SMNBC News   10/31 - 11/6  30145 LV  1.0
# 15                   Reuters/IpsosReuters   10/31 - 11/4   2244 LV  2.2
# 16                           GravisGravis  10/31 - 10/31   5360 RV  1.3
# 17                   Reuters/IpsosReuters   10/30 - 11/3   2021 LV  2.5
# 18              Economist/YouGovEconomist   10/30 - 11/1   1233 LV  3.2
# 19                   Reuters/IpsosReuters   10/29 - 11/2   1858 LV  2.6
#
#     Clinton (D)  Trump (R)        Spread  diff
# 0          48.2       46.2  Clinton +2.0   2.0
# 1          46.8       43.6  Clinton +3.2   3.2
# 2          46.0       43.0    Clinton +3   3.0
# 3          43.0       42.0    Clinton +1   1.0
# 4          49.0       45.0    Clinton +4   4.0
# 5          44.0       47.0      Trump +3  -3.0
# 6          49.0       46.0    Clinton +3   3.0
# 7          48.0       44.0    Clinton +4   4.0
# 8          50.0       44.0    Clinton +6   6.0
# 9          48.0       43.0    Clinton +5   5.0
# 10         47.0       43.0    Clinton +4   4.0
# 11         44.0       39.0    Clinton +5   5.0
# 12         46.0       44.0    Clinton +2   2.0
# 13         46.0       45.0    Clinton +1   1.0
# 14         51.0       44.0    Clinton +7   7.0
# 15         44.0       40.0    Clinton +4   4.0
# 16         50.0       50.0           Tie   0.0
# 17         44.0       39.0    Clinton +5   5.0
# 18         48.0       45.0    Clinton +3   3.0
# 19         45.0       39.0    Clinton +6   6.0
