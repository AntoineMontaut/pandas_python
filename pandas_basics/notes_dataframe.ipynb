# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'name': ['Ted', 'Ned', 'Jed'],
                   'Phone': ['Samsung', 'Samsung', 'IOS'],
                   'Favorite Number': [99, 7, 4]})
df
# Out:
#    Favorite Number    Phone name
# 0               99  Samsung  Ted
# 1                7  Samsung  Ned
# 2                4      IOS  Jed

# %%
d = {'name': ['Ted', 'Ned', 'Jed'],
                   'Phone': ['Samsung', 'Samsung', 'IOS'],
                   'Favorite Number': [99, 7, 4]}
df = pd.DataFrame(d, index=list('abc'))
df
# Out:
#    Favorite Number    Phone name
# a               99  Samsung  Ted
# b                7  Samsung  Ned
# c                4      IOS  Jed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, a to c
# Data columns (total 3 columns):
# Favorite Number    3 non-null int64
# Phone              3 non-null object
# name               3 non-null object
# dtypes: int64(1), object(2)
# memory usage: 96.0+ bytes

# %%
df.values
# Out:
# array([[99, 'Samsung', 'Ted'],
#        [7, 'Samsung', 'Ned'],
#        [4, 'IOS', 'Jed']], dtype=object)

# %%
ls data
# Out:
#  Volume in drive C is Razer Blade
#  Volume Serial Number is 2C21-3D75
#
#  Directory of C:\Users\Antoine\Documents\python_class_dec16\data
#
# 12/12/2016  11:52 AM    <DIR>          .
# 12/12/2016  11:52 AM    <DIR>          ..
# 12/12/2016  11:52 AM           738,635 coh_employee.csv
# 12/12/2016  11:52 AM         1,252,058 college.csv
# 12/12/2016  11:52 AM             1,055 college_data_dictionary.csv
#                3 File(s)      1,991,748 bytes
#                2 Dir(s)  85,970,010,112 bytes free

# %% [markdown]
# ### Houston City Employees
# Note: not the full dataset

# %%
coh = pd.read_csv('data/coh_employee.csv')

# %%
coh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 31 columns):
# UNIQUE_ID               2000 non-null int64
# FIRST_NAME              2000 non-null object
# LAST_NAME               2000 non-null object
# POSITION_NUMBER         2000 non-null int64
# POSITION_JOB_CODE       2000 non-null float64
# POSITION_TITLE          2000 non-null object
# BUSINESS_AREA           2000 non-null int64
# DEPARTMENT              2000 non-null object
# PAY_GRADE               2000 non-null object
# FUND_ID                 2000 non-null int64
# FUND_NAME               2000 non-null object
# COST_CENTER             2000 non-null int64
# COST_CENTER_NAME        2000 non-null object
# REPORTS_TO_POSITION     1688 non-null float64
# MANAGER_NAME            1678 non-null object
# BASE_SALARY             1886 non-null float64
# ORG_UNIT                2000 non-null object
# ORG_UNIT_NAME           2000 non-null object
# ...

# %%
coh.describe(include=['object'])
# Out:
#        FIRST_NAME LAST_NAME         POSITION_TITLE  \
# count        2000      2000                   2000
# unique        961      1371                    330
# top       MICHAEL   JOHNSON  SENIOR POLICE OFFICER
# freq           44        30                    220
#
#                            DEPARTMENT PAY_GRADE     FUND_NAME  \
# count                            2000      2000          2000
# unique                             24        80            39
# top     Houston Police Department-HPD      PA03  General Fund
# freq                              638       184          1304
#
#        COST_CENTER_NAME     MANAGER_NAME ORG_UNIT              ORG_UNIT_NAME  \
# count              2000             1678     2000                       2000
# unique              448             1201     1181                        478
# top      HFD-Deployment  HERMAN GONZALES  12.1210  HFD-FIRE & EMS OPERATIONS
# freq                297               56      288                        289
#
# ...

# %%
coh.BASE_SALARY.describe()
#same as
coh['BASE_SALARY'].describe()
# Out:
# count      1886.000000
# mean      55767.931601
# std       21693.706679
# min       24960.000000
# 25%       40170.000000
# 50%       54461.000000
# 75%       66614.000000
# max      275000.000000
# Name: BASE_SALARY, dtype: float64

# %%
pd.__version__
# Out:
# '0.19.1'

# %%
coh.shape
# Out:
# (2000, 31)

# %%
coh.size
# Out:
# 62000

# %%
# coh.iloc[:5,:16].head()
# coh.iloc[:5,16:].head()
pd.options.display.max_columns = 40
coh.head()
# Out:
#    UNIQUE_ID FIRST_NAME   LAST_NAME  POSITION_NUMBER  POSITION_JOB_CODE  \
# 0       9172    LILLIAN      WARDEN         30027193              306.2
# 1      12311  ESPERANZA   RODRIGUEZ         30044399              901.2
# 2      28693   JONATHAN  JORSCH JR.         30063393              108.0
# 3       2359       JOHN        HARE         30007418              103.2
# 4       5123    RUSSELL   GALBREATH         30006294              523.2
#
#                 POSITION_TITLE  BUSINESS_AREA                     DEPARTMENT  \
# 0  ASSISTANT DIRECTOR (EX LVL)           1600    Municipal Courts Department
# 1            LIBRARY ASSISTANT           3400                        Library
# 2               POLICE OFFICER           1000  Houston Police Department-HPD
# 3            ENGINEER/OPERATOR           1200  Houston Fire Department (HFD)
# 4                  ELECTRICIAN           2500    General Services Department
#
# ...

# %% [markdown]
# ### Pandas uses Numpy data types and unique Pandas data types
# (example: strings are "object")

# %%
coh.describe(include=['object']) # look at df.info() for what is a dtype "object"
# Out:
#        FIRST_NAME LAST_NAME         POSITION_TITLE  \
# count        2000      2000                   2000
# unique        961      1371                    330
# top       MICHAEL   JOHNSON  SENIOR POLICE OFFICER
# freq           44        30                    220
#
#                            DEPARTMENT PAY_GRADE     FUND_NAME  \
# count                            2000      2000          2000
# unique                             24        80            39
# top     Houston Police Department-HPD      PA03  General Fund
# freq                              638       184          1304
#
#        COST_CENTER_NAME     MANAGER_NAME ORG_UNIT              ORG_UNIT_NAME  \
# count              2000             1678     2000                       2000
# unique              448             1201     1181                        478
# top      HFD-Deployment  HERMAN GONZALES  12.1210  HFD-FIRE & EMS OPERATIONS
# freq                297               56      288                        289
#
# ...

# %%
coh[['FIRST_NAME', 'LAST_NAME']].head(3)
# Out:
#   FIRST_NAME   LAST_NAME
# 0    LILLIAN      WARDEN
# 1  ESPERANZA   RODRIGUEZ
# 2   JONATHAN  JORSCH JR.

# %%
coh.iloc[:2]
# Out:
#    UNIQUE_ID FIRST_NAME  LAST_NAME  POSITION_NUMBER  POSITION_JOB_CODE  \
# 0       9172    LILLIAN     WARDEN         30027193              306.2
# 1      12311  ESPERANZA  RODRIGUEZ         30044399              901.2
#
#                 POSITION_TITLE  BUSINESS_AREA                   DEPARTMENT  \
# 0  ASSISTANT DIRECTOR (EX LVL)           1600  Municipal Courts Department
# 1            LIBRARY ASSISTANT           3400                      Library
#
#   PAY_GRADE  FUND_ID     FUND_NAME  COST_CENTER    COST_CENTER_NAME  \
# 0        32     1000  General Fund   1600010001  MCD-Admin Services
# 1        05     1000  General Fund   3400070001  HPL-Neigh Lib Syst
#
#    REPORTS_TO_POSITION        MANAGER_NAME  BASE_SALARY    ORG_UNIT  \
# 0           30044747.0        NELLY SANTOS     121862.0     16.1410
# 1           30044159.0  MIGDALIA SEPULVEDA      26125.0  34.7001.27
#
#                        ORG_UNIT_NAME ETHNICITY             RACE  \
# ...

# %%
coh.iloc[:2, :2]
# Out:
#    UNIQUE_ID FIRST_NAME
# 0       9172    LILLIAN
# 1      12311  ESPERANZA

# %% [markdown]
# ## df.column. allows to keep using tab

# %%
coh.FIRST_NAME.count()
# Out:
# 2000

# %%
coh[coh.POSITION_TITLE == 'LIBRARY ASSISTANT']
# Out:
#       UNIQUE_ID FIRST_NAME  LAST_NAME  POSITION_NUMBER  POSITION_JOB_CODE  \
# 1         12311  ESPERANZA  RODRIGUEZ         30044399              901.2
# 840       19126     KANDIS   FRANKLIN         30027764              901.2
# 917        7550    DENETRA     HUNTER         30044253              901.2
# 1846      14973     MY-VAN      PHUNG         30055719              901.2
#
#          POSITION_TITLE  BUSINESS_AREA DEPARTMENT PAY_GRADE  FUND_ID  \
# 1     LIBRARY ASSISTANT           3400    Library        05     1000
# 840   LIBRARY ASSISTANT           3400    Library        05     1000
# 917   LIBRARY ASSISTANT           3400    Library        05     1000
# 1846  LIBRARY ASSISTANT           3400    Library        05     1000
#
#          FUND_NAME  COST_CENTER    COST_CENTER_NAME  REPORTS_TO_POSITION  \
# 1     General Fund   3400070001  HPL-Neigh Lib Syst           30044159.0
# 840   General Fund   3400070001  HPL-Neigh Lib Syst           30044168.0
# ...

# %%
coh.loc[coh.POSITION_TITLE.str.endswith('ANT'), 'POSITION_TITLE'].unique()
# Out:
# array(['LIBRARY ASSISTANT', 'POLICE SERGEANT', 'SENIOR ACCOUNTANT',
#        'DENTAL ASSISTANT', 'POLICE LIEUTENANT', 'ADMINISTRATIVE ASSISTANT',
#        'JAIL ATTENDANT', 'RECREATION ASSISTANT',
#        'HUMAN RESOURCES ASSISTANT', 'CLINIC ASSISTANT', 'CAR ATTENDANT',
#        'SENIOR OFFICE ASSISTANT', 'AIRPORT OPERATIONS ASSISTANT',
#        'SENIOR LIBRARY ASSISTANT', 'EXECUTIVE OFFICE ASSISTANT',
#        'NUTRITIONIST CONSULTANT'], dtype=object)

# %%
# coh.POSITION_TITLE.value_counts().sort_index()

# %%
coh.RACE.value_counts()
# Out:
# Black or African American            700
# White                                665
# Hispanic/Latino                      480
# Asian/Pacific Islander               107
# American Indian or Alaskan Native     11
# Others                                 2
# Name: RACE, dtype: int64

# %%
coh[((coh.GENDER == 'Female') & (coh.RACE == 'Black or African American')) | (coh.POSITION_TITLE == 'FIRE FIGHTER')].shape
# Out:
# (443, 31)

# %%
# coh.loc[coh.RACE == 'Black or African American', 'POSITION_TITLE'].unique()

# %% [markdown]
# ### Only use .ix when necessary!

# %%
coh.ix[:5, ['FIRST_NAME', 'LAST_NAME']]
# Out:
#   FIRST_NAME   LAST_NAME
# 0    LILLIAN      WARDEN
# 1  ESPERANZA   RODRIGUEZ
# 2   JONATHAN  JORSCH JR.
# 3       JOHN        HARE
# 4    RUSSELL   GALBREATH
# 5      CRAIG    PENNAMON

# %%
coh['FULL_NAME'] = coh.FIRST_NAME + ' ' + coh.LAST_NAME
coh[['FIRST_NAME', 'LAST_NAME', 'FULL_NAME']].head()
# Out:
#   FIRST_NAME   LAST_NAME            FULL_NAME
# 0    LILLIAN      WARDEN       LILLIAN WARDEN
# 1  ESPERANZA   RODRIGUEZ  ESPERANZA RODRIGUEZ
# 2   JONATHAN  JORSCH JR.  JONATHAN JORSCH JR.
# 3       JOHN        HARE            JOHN HARE
# 4    RUSSELL   GALBREATH    RUSSELL GALBREATH

# %%
coh.FULL_NAME.value_counts().loc[coh.FULL_NAME.value_counts() > 1]
# Out:
# JUAN GARCIA             2
# JASON PHILLIPS          2
# MARK SMITH              2
# CHRISTOPHER THOMPSON    2
# RYAN JOHNSON            2
# ANTHONY JONES           2
# GREGORY SCOTT           2
# RAMON GUILLEN           2
# JUAN RODRIGUEZ          2
# ROBERT HARRIS           2
# Name: FULL_NAME, dtype: int64

# %%
coh1 = coh.iloc[:,:-1].set_index(coh.FULL_NAME)
coh1.columns.name = 'COH'
coh1.head(3)
# Out:
# COH                  UNIQUE_ID FIRST_NAME   LAST_NAME  POSITION_NUMBER  \
# FULL_NAME
# LILLIAN WARDEN            9172    LILLIAN      WARDEN         30027193
# ESPERANZA RODRIGUEZ      12311  ESPERANZA   RODRIGUEZ         30044399
# JONATHAN JORSCH JR.      28693   JONATHAN  JORSCH JR.         30063393
#
# COH                  POSITION_JOB_CODE               POSITION_TITLE  \
# FULL_NAME
# LILLIAN WARDEN                   306.2  ASSISTANT DIRECTOR (EX LVL)
# ESPERANZA RODRIGUEZ              901.2            LIBRARY ASSISTANT
# JONATHAN JORSCH JR.              108.0               POLICE OFFICER
#
# COH                  BUSINESS_AREA                     DEPARTMENT PAY_GRADE  \
# FULL_NAME
# LILLIAN WARDEN                1600    Municipal Courts Department        32
# ESPERANZA RODRIGUEZ           3400                        Library        05
# JONATHAN JORSCH JR.           1000  Houston Police Department-HPD      PA03
#
# ...

# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = 40
hou = pd.read_csv('data/coh_employee.csv')

# %%
for col in hou.columns:
    print(col)
# Out:
# UNIQUE_ID
# FIRST_NAME
# LAST_NAME
# POSITION_NUMBER
# POSITION_JOB_CODE
# POSITION_TITLE
# BUSINESS_AREA
# DEPARTMENT
# PAY_GRADE
# FUND_ID
# FUND_NAME
# COST_CENTER
# COST_CENTER_NAME
# REPORTS_TO_POSITION
# MANAGER_NAME
# BASE_SALARY
# ORG_UNIT
# ORG_UNIT_NAME
# ETHNICITY
# RACE
# EMPLOYMENT_TYPE
# EMPLOYMENT_SUB_GROUP
# EXEMPT
# GENDER
# EMPLOYMENT_STATUS
# CIVIL_SERVICE_TYPE
# HIRE_DATE
# JOB_DATE
# COMP_DATE
# EEOJ
# SNAPSHOT_DATE
